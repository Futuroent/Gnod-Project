# %% [markdown]
# # Installing Spotipy

# %% [markdown]
# ## Loading credentials from the config file

# %% [markdown]
# #### Make sure that you have stored your spotify client_id and client_secret in a separate config.py file
# #### Once that's done, we import it

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials


# Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# Empty list to store all the results
all_results = []

# We need to iterate because the API only allows a max of 50 results per request
for offset in range(0, 200, 50):  # range(0, 200, 50) generates 0, 50, 100, 150
    results = sp.search(q="love", limit=50, offset=offset, market="GB")
    all_results.extend(results['tracks']['items'])  # Append the track items to our list

print("Total number of songs collected: ", len(all_results))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:730, in HTTPSConnection.connect(self)
#     728 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 730 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     731     sock=sock,
#     732     cert_reqs=self.cert_reqs,
#     733     ssl_version=self.ssl_version,
#     734     ssl_minimum_version=self.ssl_minimum_version,
#     735     ssl_maximum_version=self.ssl_maximum_version,
#     736     ca_certs=self.ca_certs,
#     737     ca_cert_dir=self.ca_cert_dir,
#     738     ca_cert_data=self.ca_cert_data,
#     739     cert_file=self.cert_file,
#     740     key_file=self.key_file,
#     741     key_password=self.key_password,
#     742     server_hostname=server_hostname_rm_dot,
#     743     ssl_context=self.ssl_context,
#     744     tls_in_tls=tls_in_tls,
#     745     assert_hostname=self.assert_hostname,
#     746     assert_fingerprint=self.assert_fingerprint,
#     747 )
#     748 self.sock = sock_and_verified.socket
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:909, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     907         server_hostname = normalized
# --> 909 ssl_sock = ssl_wrap_socket(
#     910     sock=sock,
#     911     keyfile=key_file,
#     912     certfile=cert_file,
#     913     key_password=key_password,
#     914     ca_certs=ca_certs,
#     915     ca_cert_dir=ca_cert_dir,
#     916     ca_cert_data=ca_cert_data,
#     917     server_hostname=server_hostname,
#     918     ssl_context=context,
#     919     tls_in_tls=tls_in_tls,
#     920 )
#     922 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:469, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     467 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 469 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     470 return ssl_sock
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:513, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     511     return SSLTransport(sock, ssl_context, server_hostname)
# --> 513 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:730, in HTTPSConnection.connect(self)
#     728 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 730 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     731     sock=sock,
#     732     cert_reqs=self.cert_reqs,
#     733     ssl_version=self.ssl_version,
#     734     ssl_minimum_version=self.ssl_minimum_version,
#     735     ssl_maximum_version=self.ssl_maximum_version,
#     736     ca_certs=self.ca_certs,
#     737     ca_cert_dir=self.ca_cert_dir,
#     738     ca_cert_data=self.ca_cert_data,
#     739     cert_file=self.cert_file,
#     740     key_file=self.key_file,
#     741     key_password=self.key_password,
#     742     server_hostname=server_hostname_rm_dot,
#     743     ssl_context=self.ssl_context,
#     744     tls_in_tls=tls_in_tls,
#     745     assert_hostname=self.assert_hostname,
#     746     assert_fingerprint=self.assert_fingerprint,
#     747 )
#     748 self.sock = sock_and_verified.socket
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:909, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     907         server_hostname = normalized
# --> 909 ssl_sock = ssl_wrap_socket(
#     910     sock=sock,
#     911     keyfile=key_file,
#     912     certfile=cert_file,
#     913     key_password=key_password,
#     914     ca_certs=ca_certs,
#     915     ca_cert_dir=ca_cert_dir,
#     916     ca_cert_data=ca_cert_data,
#     917     server_hostname=server_hostname,
#     918     ssl_context=context,
#     919     tls_in_tls=tls_in_tls,
#     920 )
#     922 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:469, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     467 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 469 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     470 return ssl_sock
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:513, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     511     return SSLTransport(sock, ssl_context, server_hostname)
# --> 513 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[83], line 16
#      14 # We need to iterate because the API only allows a max of 50 results per request
#      15 for offset in range(0, 200, 50):  # range(0, 200, 50) generates 0, 50, 100, 150
# ---> 16     results = sp.search(q="love", limit=50, offset=offset, market="GB")
#      17     all_results.extend(results['tracks']['items'])  # Append the track items to our list
#      19 print("Total number of songs collected: ", len(all_results))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:602, in Spotify.search(self, q, limit, offset, type, market)
#     587 def search(self, q, limit=10, offset=0, type="track", market=None):
#     588     """ searches for an item
#     589
#     590         Parameters:
#    (...)
#     600                        from_token.
#     601     """
# --> 602     return self._get(
#     603         "search", q=q, limit=limit, offset=offset, type=type, market=market
#     604     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:251, in Spotify._internal_call(self, method, url, payload, params)
#     249 if not url.startswith("http"):
#     250     url = self.prefix + url
# --> 251 headers = self._auth_headers()
#     253 if "content_type" in args["params"]:
#     254     headers["Content-Type"] = args["params"]["content_type"]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:242, in Spotify._auth_headers(self)
#     240     return {}
#     241 try:
# --> 242     token = self.auth_manager.get_access_token(as_dict=False)
#     243 except TypeError:
#     244     token = self.auth_manager.get_access_token()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/oauth2.py:229, in SpotifyClientCredentials.get_access_token(self, as_dict, check_cache)
#     226     if token_info and not self.is_token_expired(token_info):
#     227         return token_info if as_dict else token_info["access_token"]
# --> 229 token_info = self._request_access_token()
#     230 token_info = self._add_custom_values_to_token_info(token_info)
#     231 self.cache_handler.save_token_to_cache(token_info)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/oauth2.py:248, in SpotifyClientCredentials._request_access_token(self)
#     242 logger.debug(
#     243     "sending POST request to %s with Headers: %s and Body: %r",
#     244     self.OAUTH_TOKEN_URL, headers, payload
#     245 )
#     247 try:
# --> 248     response = self._session.post(
#     249         self.OAUTH_TOKEN_URL,
#     250         data=payload,
#     251         headers=headers,
#     252         verify=True,
#     253         proxies=self.proxies,
#     254         timeout=self.requests_timeout,
#     255     )
#     256     response.raise_for_status()
#     257     token_info = response.json()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Shape+of+You&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#      'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#      'id': '3T4tUhGYeRNVUGevb0wThu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#        'width': 64}],
#      'name': '÷ (Deluxe)',
#      'release_date': '2017-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 233712,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1600463'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3'},
#     'href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3',
#     'id': '7qiZfU4dY1lWllzX7mPBI3',
#     'is_local': False,
#     'name': 'Shape of You',
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7339548839a263fd721d01eb3364a848cad16fa7?cid=a488bdba33574b13b7324548f9e189af',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#      'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#      'id': '1NAmidJlEaVgA3MpcPFYGq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#        'width': 64}],
#      'name': 'Lover',
#      'release_date': '2019-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 178426,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11901472'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr'},
#     'href': 'https://api.spotify.com/v1/tracks/1BxfuPKGuaTgP7aM0Bbdwr',
#     'id': '1BxfuPKGuaTgP7aM0Bbdwr',
#     'is_local': False,
#     'name': 'Cruel Summer',
#     'popularity': 90,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0LWRykrSX54AWiMZlV5uUk'},
#      'href': 'https://api.spotify.com/v1/albums/0LWRykrSX54AWiMZlV5uUk',
#      'id': '0LWRykrSX54AWiMZlV5uUk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/621d2909bcc2c26cd0b274aab0414c9d422a1576',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/c976bfc96d5e44820e553a16a6097cd02a61fd2f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/089726b25ce5a55b906b3b65580a517b65c7c881',
#        'width': 64}],
#      'name': 'Shape of You (feat. Zion & Lennox) [Latin Remix]',
#      'release_date': '2017-03-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0LWRykrSX54AWiMZlV5uUk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jBa39W2cucJozDpEBtCXu'},
#       'href': 'https://api.spotify.com/v1/artists/2jBa39W2cucJozDpEBtCXu',
#       'id': '2jBa39W2cucJozDpEBtCXu',
#       'name': 'Lennox',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jBa39W2cucJozDpEBtCXu'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1pgDilWYDWLoOgGjf1iHNu'},
#       'href': 'https://api.spotify.com/v1/artists/1pgDilWYDWLoOgGjf1iHNu',
#       'id': '1pgDilWYDWLoOgGjf1iHNu',
#       'name': 'Zion',
#       'type': 'artist',
#       'uri': 'spotify:artist:1pgDilWYDWLoOgGjf1iHNu'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 237664,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700245'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5nCtCCB5i1OfbADvynNw0i'},
#     'href': 'https://api.spotify.com/v1/tracks/5nCtCCB5i1OfbADvynNw0i',
#     'id': '5nCtCCB5i1OfbADvynNw0i',
#     'is_local': False,
#     'name': 'Shape of You (feat. Zion & Lennox) - Latin Remix',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/945688fa0cfe1ad9f1fd490beab1c6671f3cfebe?cid=a488bdba33574b13b7324548f9e189af',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5nCtCCB5i1OfbADvynNw0i'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5xD1PSd5c5APDM0SdkkqnH'},
#      'href': 'https://api.spotify.com/v1/albums/5xD1PSd5c5APDM0SdkkqnH',
#      'id': '5xD1PSd5c5APDM0SdkkqnH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f3b7c61765b74bd5cbce636',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f3b7c61765b74bd5cbce636',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f3b7c61765b74bd5cbce636',
#        'width': 64}],
#      'name': '+-=÷× (TOUR COLLECTION)',
#      'release_date': '2024-09-27',
#      'release_date_precision': 'day',
#      'total_tracks': 24,
#      'type': 'album',
#      'uri': 'spotify:album:5xD1PSd5c5APDM0SdkkqnH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 233712,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1600463'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2sMTmMYviXS6bgsWMTDZhB'},
#     'href': 'https://api.spotify.com/v1/tracks/2sMTmMYviXS6bgsWMTDZhB',
#     'id': '2sMTmMYviXS6bgsWMTDZhB',
#     'is_local': False,
#     'name': 'Shape of You',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3248db01c0853f0fcb6fc9c086da24843138ad15?cid=a488bdba33574b13b7324548f9e189af',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:2sMTmMYviXS6bgsWMTDZhB'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RQXRUsr4IW1f3mKyKsy4B'},
#        'href': 'https://api.spotify.com/v1/artists/2RQXRUsr4IW1f3mKyKsy4B',
#        'id': '2RQXRUsr4IW1f3mKyKsy4B',
#        'name': 'Noah Kahan',
#        'type': 'artist',
#        'uri': 'spotify:artist:2RQXRUsr4IW1f3mKyKsy4B'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#        'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#        'id': '246dkjvS1zLTtiykXe5h60',
#        'name': 'Post Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4XahqkOmEsKLKEhBpX8DAe'},
#      'href': 'https://api.spotify.com/v1/albums/4XahqkOmEsKLKEhBpX8DAe',
#      'id': '4XahqkOmEsKLKEhBpX8DAe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f519f148d88bf65074b4a3a9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f519f148d88bf65074b4a3a9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f519f148d88bf65074b4a3a9',
#        'width': 64}],
#      'name': 'Dial Drunk (with Post Malone)',
#      'release_date': '2023-07-18',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4XahqkOmEsKLKEhBpX8DAe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2RQXRUsr4IW1f3mKyKsy4B'},
#       'href': 'https://api.spotify.com/v1/artists/2RQXRUsr4IW1f3mKyKsy4B',
#       'id': '2RQXRUsr4IW1f3mKyKsy4B',
#       'name': 'Noah Kahan',
#       'type': 'artist',
#       'uri': 'spotify:artist:2RQXRUsr4IW1f3mKyKsy4B'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 213817,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM72308676'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/22VHOlVYBqytsrAqV8yXBK'},
#     'href': 'https://api.spotify.com/v1/tracks/22VHOlVYBqytsrAqV8yXBK',
#     'id': '22VHOlVYBqytsrAqV8yXBK',
#     'is_local': False,
#     'name': 'Dial Drunk (with Post Malone)',
#     'popularity': 81,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:22VHOlVYBqytsrAqV8yXBK'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/10Z7WzKMeIdNBKexi1YarP'},
#        'href': 'https://api.spotify.com/v1/artists/10Z7WzKMeIdNBKexi1YarP',
#        'id': '10Z7WzKMeIdNBKexi1YarP',
#        'name': 'Fame on Fire',
#        'type': 'artist',
#        'uri': 'spotify:artist:10Z7WzKMeIdNBKexi1YarP'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'DJ',
#       'ZM',
#       'CG',
#       'TJ',
#       'VE',
#       'ET'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4eYjV7ET5e8iOtyxg5CLNq'},
#      'href': 'https://api.spotify.com/v1/albums/4eYjV7ET5e8iOtyxg5CLNq',
#      'id': '4eYjV7ET5e8iOtyxg5CLNq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27336af4da408a79320bb873b49',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0236af4da408a79320bb873b49',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485136af4da408a79320bb873b49',
#        'width': 64}],
#      'name': 'Shape of You',
#      'release_date': '2017-01-29',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4eYjV7ET5e8iOtyxg5CLNq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/10Z7WzKMeIdNBKexi1YarP'},
#       'href': 'https://api.spotify.com/v1/artists/10Z7WzKMeIdNBKexi1YarP',
#       'id': '10Z7WzKMeIdNBKexi1YarP',
#       'name': 'Fame on Fire',
#       'type': 'artist',
#       'uri': 'spotify:artist:10Z7WzKMeIdNBKexi1YarP'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'DJ',
#      'ZM',
#      'CG',
#      'TJ',
#      'VE',
#      'ET'],
#     'disc_number': 1,
#     'duration_ms': 236250,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACX1729283'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/54SMw8TnDcuieolVRXBmni'},
#     'href': 'https://api.spotify.com/v1/tracks/54SMw8TnDcuieolVRXBmni',
#     'id': '54SMw8TnDcuieolVRXBmni',
#     'is_local': False,
#     'name': 'Shape of You',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a3d580ad02d52c22d9dccbe02cc7cbb58d522fda?cid=a488bdba33574b13b7324548f9e189af',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:54SMw8TnDcuieolVRXBmni'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RKnXXyprPjhBdCvL802Ku'},
#        'href': 'https://api.spotify.com/v1/artists/6RKnXXyprPjhBdCvL802Ku',
#        'id': '6RKnXXyprPjhBdCvL802Ku',
#        'name': 'I.O.I',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RKnXXyprPjhBdCvL802Ku'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2YyowuE62RMWFtBSa2EO7r'},
#      'href': 'https://api.spotify.com/v1/albums/2YyowuE62RMWFtBSa2EO7r',
#      'id': '2YyowuE62RMWFtBSa2EO7r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273266f95f6353cb2b974f67fa7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02266f95f6353cb2b974f67fa7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851266f95f6353cb2b974f67fa7',
#        'width': 64}],
#      'name': 'miss me?',
#      'release_date': '2016-10-17',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:2YyowuE62RMWFtBSa2EO7r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RKnXXyprPjhBdCvL802Ku'},
#       'href': 'https://api.spotify.com/v1/artists/6RKnXXyprPjhBdCvL802Ku',
#       'id': '6RKnXXyprPjhBdCvL802Ku',
#       'name': 'I.O.I',
#       'type': 'artist',
#       'uri': 'spotify:artist:6RKnXXyprPjhBdCvL802Ku'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 203640,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA381602024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0BhMw9r3eOLMLXRFBLCt6O'},
#     'href': 'https://api.spotify.com/v1/tracks/0BhMw9r3eOLMLXRFBLCt6O',
#     'id': '0BhMw9r3eOLMLXRFBLCt6O',
#     'is_local': False,
#     'name': 'Very Very Very',
#     'popularity': 54,
#     'preview_url': 'https://p.scdn.co/mp3-preview/277fa258f048a9c9cc9ffe9948c5e7106129e29a?cid=a488bdba33574b13b7324548f9e189af',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0BhMw9r3eOLMLXRFBLCt6O'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
# ...
#       'name': 'Kranium',
#       'type': 'artist',
#       'uri': 'spotify:artist:1LKo6ZA3RNvKtLa6zDu32S'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/738wLrAtLtCtFOLvQBXOXp'},
#       'href': 'https://api.spotify.com/v1/artists/738wLrAtLtCtFOLvQBXOXp',
#       'id': '738wLrAtLtCtFOLvQBXOXp',
#       'name': 'Major Lazer',
#       'type': 'artist',
#       'uri': 'spotify:artist:738wLrAtLtCtFOLvQBXOXp'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 192000,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS1700228'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KqvRRQd3lfM0pAlkGPrgD'},
#     'href': 'https://api.spotify.com/v1/tracks/1KqvRRQd3lfM0pAlkGPrgD',
#     'id': '1KqvRRQd3lfM0pAlkGPrgD',
#     'is_local': False,
#     'name': 'Shape of You (feat. Nyla & Kranium) - Major Lazer Remix',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/76ae9fa5df152e3535344df350c9c04e35117077?cid=a488bdba33574b13b7324548f9e189af',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1KqvRRQd3lfM0pAlkGPrgD'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#        'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#        'id': '66CXWjxzNUsdJxJ2JdwvnR',
#        'name': 'Ariana Grande',
#        'type': 'artist',
#        'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5X7x18kW3mVIvnuNeedM6b'},
#      'href': 'https://api.spotify.com/v1/albums/5X7x18kW3mVIvnuNeedM6b',
#      'id': '5X7x18kW3mVIvnuNeedM6b',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732e651648db439a9b5995e065',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022e651648db439a9b5995e065',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512e651648db439a9b5995e065',
#        'width': 64}],
#      'name': 'Dangerous Woman',
#      'release_date': '2016-05-20',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:5X7x18kW3mVIvnuNeedM6b'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/66CXWjxzNUsdJxJ2JdwvnR'},
#       'href': 'https://api.spotify.com/v1/artists/66CXWjxzNUsdJxJ2JdwvnR',
#       'id': '66CXWjxzNUsdJxJ2JdwvnR',
#       'name': 'Ariana Grande',
#       'type': 'artist',
#       'uri': 'spotify:artist:66CXWjxzNUsdJxJ2JdwvnR'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 244440,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71601827'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/49gRYU6hBWgSH2JVixGkJq'},
#     'href': 'https://api.spotify.com/v1/tracks/49gRYU6hBWgSH2JVixGkJq',
#     'id': '49gRYU6hBWgSH2JVixGkJq',
#     'is_local': False,
#     'name': 'Into You',
#     'popularity': 65,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:49gRYU6hBWgSH2JVixGkJq'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17pyV0hn7BcEd4esh9GvHX'},
#        'href': 'https://api.spotify.com/v1/artists/17pyV0hn7BcEd4esh9GvHX',
#        'id': '17pyV0hn7BcEd4esh9GvHX',
#        'name': 'Brennan Lynch',
#        'type': 'artist',
#        'uri': 'spotify:artist:17pyV0hn7BcEd4esh9GvHX'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0eckGnMcCO8sFG2bt4zDMA'},
#      'href': 'https://api.spotify.com/v1/albums/0eckGnMcCO8sFG2bt4zDMA',
#      'id': '0eckGnMcCO8sFG2bt4zDMA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273915e047c1153bd8700b47dcf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02915e047c1153bd8700b47dcf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851915e047c1153bd8700b47dcf',
#        'width': 64}],
#      'name': 'Shape of You',
#      'release_date': '2023-09-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0eckGnMcCO8sFG2bt4zDMA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17pyV0hn7BcEd4esh9GvHX'},
#       'href': 'https://api.spotify.com/v1/artists/17pyV0hn7BcEd4esh9GvHX',
#       'id': '17pyV0hn7BcEd4esh9GvHX',
#       'name': 'Brennan Lynch',
#       'type': 'artist',
#       'uri': 'spotify:artist:17pyV0hn7BcEd4esh9GvHX'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 166897,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5W32308498'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/67QFTpuf9NUmfi490Uh16b'},
#     'href': 'https://api.spotify.com/v1/tracks/67QFTpuf9NUmfi490Uh16b',
#     'id': '67QFTpuf9NUmfi490Uh16b',
#     'is_local': False,
#     'name': 'Shape of You',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/68b0ca95609dff18f597d1d9468b8264b9c6a73c?cid=a488bdba33574b13b7324548f9e189af',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:67QFTpuf9NUmfi490Uh16b'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Shape+of+You&type=track&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 1000}}

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Shape+of+You&type=track&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#                                               'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#                                               'id': '6eUKZXaKkcviH0Ku9w2n3V',
#                                               'name': 'Ed Sheeran',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'BY',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#                                  'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#                                  'id': '3T4tUhGYeRNVUGevb0wThu',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#                                              'width': 64}],
#                                  'name': '÷ (Deluxe)',
#                                  'release_date': '2017-03-03',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 16,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#                                     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#                                     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#                                     'name': 'Ed Sheeran',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 233712,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBAHS1600463'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3'},
#                        'href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3',
#                        'id': '7qiZfU4dY1lWllzX7mPBI3',
#                        'is_local': False,
#                        'name': 'Shape of You',
#                        'popularity': 85,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/7339548839a263fd721d01eb3364a848cad16fa7?cid=a488bdba33574b13b7324548f9e189af',
#                        'track_number': 4,
#                        'type': 'track',
#                        'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#                                               'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#                                               'id': '06HL4z0CvFAxyc27GXpf02',
#                                               'name': 'Taylor Swift',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#                                  'available_markets': ['AR',
#                                                        'AU',
#                                                        'AT',
#                                                        'BE',
#                                                        'BO',
#                                                        'BR',
#                                                        'BG',
#                                                        'CA',
#                                                        'CL',
#                                                        'CO',
#                                                        'CR',
#                                                        'CY',
#                                                        'CZ',
#                                                        'DK',
#                                                        'DO',
#                                                        'DE',
#                                                        'EC',
#                                                        'EE',
#                                                        'SV',
#                                                        'FI',
#                                                        'FR',
#                                                        'GR',
#                                                        'GT',
#                                                        'HN',
#                                                        'HK',
#                                                        'HU',
#                                                        'IS',
#                                                        'IE',
#                                                        'IT',
#                                                        'LV',
#                                                        'LT',
#                                                        'LU',
#                                                        'MY',
#                                                        'MT',
#                                                        'MX',
#                                                        'NL',
#                                                        'NZ',
#                                                        'NI',
#                                                        'NO',
#                                                        'PA',
#                                                        'PY',
#                                                        'PE',
#                                                        'PH',
#                                                        'PL',
#                                                        'PT',
#                                                        'SG',
#                                                        'SK',
#                                                        'ES',
#                                                        'SE',
#                                                        'CH',
#                                                        'TW',
#                                                        'TR',
#                                                        'UY',
#                                                        'US',
#                                                        'GB',
#                                                        'AD',
#                                                        'LI',
#                                                        'MC',
#                                                        'ID',
#                                                        'JP',
#                                                        'TH',
#                                                        'VN',
#                                                        'RO',
#                                                        'IL',
#                                                        'ZA',
#                                                        'SA',
#                                                        'AE',
#                                                        'BH',
#                                                        'QA',
#                                                        'OM',
#                                                        'KW',
#                                                        'EG',
#                                                        'MA',
#                                                        'DZ',
#                                                        'TN',
#                                                        'LB',
#                                                        'JO',
#                                                        'PS',
#                                                        'IN',
#                                                        'BY',
#                                                        'KZ',
#                                                        'MD',
#                                                        'UA',
#                                                        'AL',
#                                                        'BA',
#                                                        'HR',
#                                                        'ME',
#                                                        'MK',
#                                                        'RS',
#                                                        'SI',
#                                                        'KR',
#                                                        'BD',
#                                                        'PK',
#                                                        'LK',
#                                                        'GH',
#                                                        'KE',
#                                                        'NG',
#                                                        'TZ',
#                                                        'UG',
#                                                        'AG',
#                                                        'AM',
#                                                        'BS',
#                                                        'BB',
#                                                        'BZ',
#                                                        'BT',
#                                                        'BW',
#                                                        'BF',
#                                                        'CV',
#                                                        'CW',
#                                                        'DM',
#                                                        'FJ',
#                                                        'GM',
#                                                        'GE',
#                                                        'GD',
#                                                        'GW',
#                                                        'GY',
#                                                        'HT',
#                                                        'JM',
#                                                        'KI',
#                                                        'LS',
#                                                        'LR',
#                                                        'MW',
#                                                        'MV',
#                                                        'ML',
#                                                        'MH',
#                                                        'FM',
#                                                        'NA',
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
#                                  'href': 'https://api.spotify.com/v1/albums/1NAmidJlEaVgA3MpcPFYGq',
#                                  'id': '1NAmidJlEaVgA3MpcPFYGq',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273e787cffec20aa2a396a61647',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02e787cffec20aa2a396a61647',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851e787cffec20aa2a396a61647',
#                                              'width': 64}],
#                                  'name': 'Lover',
#                                  'release_date': '2019-08-23',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 18,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1NAmidJlEaVgA3MpcPFYGq'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#                                     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#                                     'id': '06HL4z0CvFAxyc27GXpf02',
#                                     'name': 'Taylor Swift',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 178426,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USUG11901472'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1BxfuPKGuaTgP7aM0Bbdwr'},
#                        'href': 'https://api.spotify.com/v1/tracks/1BxfuPKGuaTgP7aM0Bbdwr',
#                        'id': '1BxfuPKGuaTgP7aM0Bbdwr',
#                        'is_local': False,
#                        'name': 'Cruel Summer',
#                        'popularity': 90,
#                        'preview_url': None,
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:1BxfuPKGuaTgP7aM0Bbdwr'},
#                       {'album': {'album_type': 'single',
# ...
#                                                        'NR',
#                                                        'NE',
#                                                        'PW',
#                                                        'PG',
#                                                        'PR',
#                                                        'WS',
#                                                        'SM',
#                                                        'ST',
#                                                        'SN',
#                                                        'SC',
#                                                        'SL',
#                                                        'SB',
#                                                        'KN',
#                                                        'LC',
#                                                        'VC',
#                                                        'SR',
#                                                        'TL',
#                                                        'TO',
#                                                        'TT',
#                                                        'TV',
#                                                        'VU',
#                                                        'AZ',
#                                                        'BN',
#                                                        'BI',
#                                                        'KH',
#                                                        'CM',
#                                                        'TD',
#                                                        'KM',
#                                                        'GQ',
#                                                        'SZ',
#                                                        'GA',
#                                                        'GN',
#                                                        'KG',
#                                                        'LA',
#                                                        'MO',
#                                                        'MR',
#                                                        'MN',
#                                                        'NP',
#                                                        'RW',
#                                                        'TG',
#                                                        'UZ',
#                                                        'ZW',
#                                                        'BJ',
#                                                        'MG',
#                                                        'MU',
#                                                        'MZ',
#                                                        'AO',
#                                                        'CI',
#                                                        'DJ',
#                                                        'ZM',
#                                                        'CD',
#                                                        'CG',
#                                                        'IQ',
#                                                        'LY',
#                                                        'TJ',
#                                                        'VE',
#                                                        'ET',
#                                                        'XK'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/0eckGnMcCO8sFG2bt4zDMA'},
#                                  'href': 'https://api.spotify.com/v1/albums/0eckGnMcCO8sFG2bt4zDMA',
#                                  'id': '0eckGnMcCO8sFG2bt4zDMA',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273915e047c1153bd8700b47dcf',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02915e047c1153bd8700b47dcf',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851915e047c1153bd8700b47dcf',
#                                              'width': 64}],
#                                  'name': 'Shape of You',
#                                  'release_date': '2023-09-22',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:0eckGnMcCO8sFG2bt4zDMA'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/17pyV0hn7BcEd4esh9GvHX'},
#                                     'href': 'https://api.spotify.com/v1/artists/17pyV0hn7BcEd4esh9GvHX',
#                                     'id': '17pyV0hn7BcEd4esh9GvHX',
#                                     'name': 'Brennan Lynch',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:17pyV0hn7BcEd4esh9GvHX'}],
#                        'available_markets': ['AR',
#                                              'AU',
#                                              'AT',
#                                              'BE',
#                                              'BO',
#                                              'BR',
#                                              'BG',
#                                              'CA',
#                                              'CL',
#                                              'CO',
#                                              'CR',
#                                              'CY',
#                                              'CZ',
#                                              'DK',
#                                              'DO',
#                                              'DE',
#                                              'EC',
#                                              'EE',
#                                              'SV',
#                                              'FI',
#                                              'FR',
#                                              'GR',
#                                              'GT',
#                                              'HN',
#                                              'HK',
#                                              'HU',
#                                              'IS',
#                                              'IE',
#                                              'IT',
#                                              'LV',
#                                              'LT',
#                                              'LU',
#                                              'MY',
#                                              'MT',
#                                              'MX',
#                                              'NL',
#                                              'NZ',
#                                              'NI',
#                                              'NO',
#                                              'PA',
#                                              'PY',
#                                              'PE',
#                                              'PH',
#                                              'PL',
#                                              'PT',
#                                              'SG',
#                                              'SK',
#                                              'ES',
#                                              'SE',
#                                              'CH',
#                                              'TW',
#                                              'TR',
#                                              'UY',
#                                              'US',
#                                              'GB',
#                                              'AD',
#                                              'LI',
#                                              'MC',
#                                              'ID',
#                                              'JP',
#                                              'TH',
#                                              'VN',
#                                              'RO',
#                                              'IL',
#                                              'ZA',
#                                              'SA',
#                                              'AE',
#                                              'BH',
#                                              'QA',
#                                              'OM',
#                                              'KW',
#                                              'EG',
#                                              'MA',
#                                              'DZ',
#                                              'TN',
#                                              'LB',
#                                              'JO',
#                                              'PS',
#                                              'IN',
#                                              'BY',
#                                              'KZ',
#                                              'MD',
#                                              'UA',
#                                              'AL',
#                                              'BA',
#                                              'HR',
#                                              'ME',
#                                              'MK',
#                                              'RS',
#                                              'SI',
#                                              'KR',
#                                              'BD',
#                                              'PK',
#                                              'LK',
#                                              'GH',
#                                              'KE',
#                                              'NG',
#                                              'TZ',
#                                              'UG',
#                                              'AG',
#                                              'AM',
#                                              'BS',
#                                              'BB',
#                                              'BZ',
#                                              'BT',
#                                              'BW',
#                                              'BF',
#                                              'CV',
#                                              'CW',
#                                              'DM',
#                                              'FJ',
#                                              'GM',
#                                              'GE',
#                                              'GD',
#                                              'GW',
#                                              'GY',
#                                              'HT',
#                                              'JM',
#                                              'KI',
#                                              'LS',
#                                              'LR',
#                                              'MW',
#                                              'MV',
#                                              'ML',
#                                              'MH',
#                                              'FM',
#                                              'NA',
#                                              'NR',
#                                              'NE',
#                                              'PW',
#                                              'PG',
#                                              'PR',
#                                              'WS',
#                                              'SM',
#                                              'ST',
#                                              'SN',
#                                              'SC',
#                                              'SL',
#                                              'SB',
#                                              'KN',
#                                              'LC',
#                                              'VC',
#                                              'SR',
#                                              'TL',
#                                              'TO',
#                                              'TT',
#                                              'TV',
#                                              'VU',
#                                              'AZ',
#                                              'BN',
#                                              'BI',
#                                              'KH',
#                                              'CM',
#                                              'TD',
#                                              'KM',
#                                              'GQ',
#                                              'SZ',
#                                              'GA',
#                                              'GN',
#                                              'KG',
#                                              'LA',
#                                              'MO',
#                                              'MR',
#                                              'MN',
#                                              'NP',
#                                              'RW',
#                                              'TG',
#                                              'UZ',
#                                              'ZW',
#                                              'BJ',
#                                              'MG',
#                                              'MU',
#                                              'MZ',
#                                              'AO',
#                                              'CI',
#                                              'DJ',
#                                              'ZM',
#                                              'CD',
#                                              'CG',
#                                              'IQ',
#                                              'LY',
#                                              'TJ',
#                                              'VE',
#                                              'ET',
#                                              'XK'],
#                        'disc_number': 1,
#                        'duration_ms': 166897,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'SE5W32308498'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/67QFTpuf9NUmfi490Uh16b'},
#                        'href': 'https://api.spotify.com/v1/tracks/67QFTpuf9NUmfi490Uh16b',
#                        'id': '67QFTpuf9NUmfi490Uh16b',
#                        'is_local': False,
#                        'name': 'Shape of You',
#                        'popularity': 50,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/68b0ca95609dff18f597d1d9468b8264b9c6a73c?cid=a488bdba33574b13b7324548f9e189af',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:67QFTpuf9NUmfi490Uh16b'}],
#             'limit': 10,
#             'next': 'https://api.spotify.com/v1/search?query=Shape+of+You&type=track&offset=10&limit=10',
#             'offset': 0,
#             'previous': None,
#             'total': 1000}}

# %% [markdown]
# # Understanding the json

# %%
print("The json file has the following keys: ",list(results.keys()))
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Shape+of+You&type=track&offset=0&limit=10
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'}, 'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V', 'id': '6eUKZXaKkcviH0Ku9w2n3V', 'name': 'Ed Sheeran', 'type': 'artist', 'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'}, 'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu', 'id': '3T4tUhGYeRNVUGevb0wThu', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96', 'width': 64}], 'name': '÷ (Deluxe)', 'release_date': '2017-03-03', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'}, 'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V', 'id': '6eUKZXaKkcviH0Ku9w2n3V', 'name': 'Ed Sheeran', 'type': 'artist', 'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'ME', 'MK', 'RS', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', 'CW', 'DM', 'FJ', 'GM', 'GE', 'GD', 'GW', 'GY', 'HT', 'JM', 'KI', 'LS', 'LR', 'MW', 'MV', 'ML', 'MH', 'FM', 'NA', 'NR', 'NE', 'PW', 'PG', 'WS', 'SM', 'ST', 'SN', 'SC', 'SL', 'SB', 'KN', 'LC', 'VC', 'SR', 'TL', 'TO', 'TT', 'TV', 'VU', 'AZ', 'BN', 'BI', 'KH', 'CM', 'TD', 'KM', 'GQ', 'SZ', 'GA', 'GN', 'KG', 'LA', 'MO', 'MR', 'MN', 'NP', 'RW', 'TG', 'UZ', 'ZW', 'BJ', 'MG', 'MU', 'MZ', 'AO', 'CI', 'DJ', 'ZM', 'CD', 'CG', 'IQ', 'LY', 'TJ', 'VE', 'ET', 'XK'], 'disc_number': 1, 'duration_ms': 233712, 'explicit': False, 'external_ids': {'isrc': 'GBAHS1600463'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3'}, 'href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3', 'id': '7qiZfU4dY1lWllzX7mPBI3', 'is_local': False, 'name': 'Shape of You', 'popularity': 85, 'preview_url': 'https://p.scdn.co/mp3-preview/7339548839a2 ...

# %% [markdown]
# ## Other Info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] 
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:7qiZfU4dY1lWllzX7mPBI3'

# %%
len(results['tracks']["items"])
# Out:
# 10

# %% [markdown]
# ## Getting the track_id

# %%
track_id = results["tracks"]["items"][0]["id"]
track_id
# Out:
# '7qiZfU4dY1lWllzX7mPBI3'

# %%
for item in all_results:
    print("The name of song is: '{}' and the id is: {}".format(item['name'], item['id']))

# %% [markdown]
# ## Embedded track player

# %%
from IPython.display import IFrame

# %%
from IPython.display import IFrame

track_id = '3CeCwYWvdfXbZLXFhBrbnf'
#track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3CeCwYWvdfXbZLXFhBrbnf?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Getting the Audio features of a song

# %%
id = results["tracks"]["items"][0]["id"]
id
# Out:
# '7qiZfU4dY1lWllzX7mPBI3'

# %%
sp.audio_features(id)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:730, in HTTPSConnection.connect(self)
#     728 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 730 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     731     sock=sock,
#     732     cert_reqs=self.cert_reqs,
#     733     ssl_version=self.ssl_version,
#     734     ssl_minimum_version=self.ssl_minimum_version,
#     735     ssl_maximum_version=self.ssl_maximum_version,
#     736     ca_certs=self.ca_certs,
#     737     ca_cert_dir=self.ca_cert_dir,
#     738     ca_cert_data=self.ca_cert_data,
#     739     cert_file=self.cert_file,
#     740     key_file=self.key_file,
#     741     key_password=self.key_password,
#     742     server_hostname=server_hostname_rm_dot,
#     743     ssl_context=self.ssl_context,
#     744     tls_in_tls=tls_in_tls,
#     745     assert_hostname=self.assert_hostname,
#     746     assert_fingerprint=self.assert_fingerprint,
#     747 )
#     748 self.sock = sock_and_verified.socket
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:909, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     907         server_hostname = normalized
# --> 909 ssl_sock = ssl_wrap_socket(
#     910     sock=sock,
#     911     keyfile=key_file,
#     912     certfile=cert_file,
#     913     key_password=key_password,
#     914     ca_certs=ca_certs,
#     915     ca_cert_dir=ca_cert_dir,
#     916     ca_cert_data=ca_cert_data,
#     917     server_hostname=server_hostname,
#     918     ssl_context=context,
#     919     tls_in_tls=tls_in_tls,
#     920 )
#     922 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:469, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     467 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 469 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     470 return ssl_sock
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:513, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     511     return SSLTransport(sock, ssl_context, server_hostname)
# --> 513 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:730, in HTTPSConnection.connect(self)
#     728 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 730 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     731     sock=sock,
#     732     cert_reqs=self.cert_reqs,
#     733     ssl_version=self.ssl_version,
#     734     ssl_minimum_version=self.ssl_minimum_version,
#     735     ssl_maximum_version=self.ssl_maximum_version,
#     736     ca_certs=self.ca_certs,
#     737     ca_cert_dir=self.ca_cert_dir,
#     738     ca_cert_data=self.ca_cert_data,
#     739     cert_file=self.cert_file,
#     740     key_file=self.key_file,
#     741     key_password=self.key_password,
#     742     server_hostname=server_hostname_rm_dot,
#     743     ssl_context=self.ssl_context,
#     744     tls_in_tls=tls_in_tls,
#     745     assert_hostname=self.assert_hostname,
#     746     assert_fingerprint=self.assert_fingerprint,
#     747 )
#     748 self.sock = sock_and_verified.socket
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:909, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     907         server_hostname = normalized
# --> 909 ssl_sock = ssl_wrap_socket(
#     910     sock=sock,
#     911     keyfile=key_file,
#     912     certfile=cert_file,
#     913     key_password=key_password,
#     914     ca_certs=ca_certs,
#     915     ca_cert_dir=ca_cert_dir,
#     916     ca_cert_data=ca_cert_data,
#     917     server_hostname=server_hostname,
#     918     ssl_context=context,
#     919     tls_in_tls=tls_in_tls,
#     920 )
#     922 try:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:469, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     467 context.set_alpn_protocols(ALPN_PROTOCOLS)
# --> 469 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     470 return ssl_sock
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:513, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     511     return SSLTransport(sock, ssl_context, server_hostname)
# --> 513 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1042, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1041                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1042             self.do_handshake()
#    1043 except:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1320, in SSLSocket.do_handshake(self, block)
#    1319         self.settimeout(None)
# -> 1320     self._sslobj.do_handshake()
#    1321 finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 sp.audio_features(id)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:1750, in Spotify.audio_features(self, tracks)
#    1748 if isinstance(tracks, str):
#    1749     trackid = self._get_id("track", tracks)
# -> 1750     results = self._get("audio-features/?ids=" + trackid)
#    1751 else:
#    1752     tlist = [self._get_id("track", t) for t in tracks]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:251, in Spotify._internal_call(self, method, url, payload, params)
#     249 if not url.startswith("http"):
#     250     url = self.prefix + url
# --> 251 headers = self._auth_headers()
#     253 if "content_type" in args["params"]:
#     254     headers["Content-Type"] = args["params"]["content_type"]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:242, in Spotify._auth_headers(self)
#     240     return {}
#     241 try:
# --> 242     token = self.auth_manager.get_access_token(as_dict=False)
#     243 except TypeError:
#     244     token = self.auth_manager.get_access_token()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/oauth2.py:229, in SpotifyClientCredentials.get_access_token(self, as_dict, check_cache)
#     226     if token_info and not self.is_token_expired(token_info):
#     227         return token_info if as_dict else token_info["access_token"]
# --> 229 token_info = self._request_access_token()
#     230 token_info = self._add_custom_values_to_token_info(token_info)
#     231 self.cache_handler.save_token_to_cache(token_info)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/oauth2.py:248, in SpotifyClientCredentials._request_access_token(self)
#     242 logger.debug(
#     243     "sending POST request to %s with Headers: %s and Body: %r",
#     244     self.OAUTH_TOKEN_URL, headers, payload
#     245 )
#     247 try:
# --> 248     response = self._session.post(
#     249         self.OAUTH_TOKEN_URL,
#     250         data=payload,
#     251         headers=headers,
#     252         verify=True,
#     253         proxies=self.proxies,
#     254         timeout=self.requests_timeout,
#     255     )
#     256     response.raise_for_status()
#     257     token_info = response.json()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song(id)
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/7qiZfU4dY1lWllzX7mPBI3?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Building a Data frame of audio features

# %%
list_of_songs=[]
song_names = []

for i in results["tracks"]["items"]:
    list_of_songs.append(i["id"])
    song_names.append(i["name"])
    

song_features = sp.audio_features(list_of_songs)

df=pd.DataFrame(song_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df["names"] = song_names

# %%
df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.825   0.652    -3.183       0.0802       0.58100
# 1         0.552   0.702    -5.707       0.1570       0.11700
# 2         0.787   0.872    -1.397       0.0871       0.16800
# 3         0.825   0.652    -3.183       0.0801       0.58100
# 4         0.669   0.606    -7.193       0.0292       0.12400
# 5         0.530   0.920    -2.912       0.0734       0.02550
# 6         0.744   0.963    -1.525       0.0616       0.13600
# 7         0.682   0.812    -2.691       0.1180       0.00574
# 8         0.623   0.734    -5.948       0.1070       0.01620
# 9         0.632   0.220   -15.383       0.0617       0.99400
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.000000    0.0931    0.931   95.977  7qiZfU4dY1lWllzX7mPBI3
# 1          0.000021    0.1050    0.564  169.994  1BxfuPKGuaTgP7aM0Bbdwr
# 2          0.000002    0.0408    0.460   95.995  5nCtCCB5i1OfbADvynNw0i
# 3          0.000000    0.0931    0.931   95.977  2sMTmMYviXS6bgsWMTDZhB
# 4          0.000000    0.1120    0.690  112.108  22VHOlVYBqytsrAqV8yXBK
# 5          0.000000    0.1680    0.738  191.977  54SMw8TnDcuieolVRXBmni
# 6          0.000002    0.0836    0.788  102.985  0BhMw9r3eOLMLXRFBLCt6O
# 7          0.000000    0.0553    0.347  104.891  1KqvRRQd3lfM0pAlkGPrgD
# 8          0.000002    0.1450    0.370  107.853  49gRYU6hBWgSH2JVixGkJq
# 9          0.925000    0.1100    0.662  150.207  67QFTpuf9NUmfi490Uh16b
#
#    duration_ms                                              names
# 0       233713                                       Shape of You
# 1       178427                                       Cruel Summer
# 2       237664   Shape of You (feat. Zion & Lennox) - Latin Remix
# 3       233713                                       Shape of You
# 4       213817                      Dial Drunk (with Post Malone)
# 5       236250                                       Shape of You
# 6       203640                                     Very Very Very
# 7       192000  Shape of You (feat. Nyla & Kranium) - Major La...
# 8       244440                                           Into You
# 9       166897                                       Shape of You

# %% [markdown]
# ## Searching a playlist

# %%
results = sp.search(q="love")
play_song(results["tracks"]["items"][0]["id"])
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/0W4NhJhcqKCqEP2GIpDCDq?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
song = input("Write your song: ")  
results = sp.search(q=song)
play_song(results["tracks"]["items"][0]["id"])
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/search with Params: {'q': '', 'limit': 10, 'offset': 0, 'type': 'track', 'market': None} returned 400 due to No search query
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:275, in Spotify._internal_call(self, method, url, payload, params)
#     270 response = self._session.request(
#     271     method, url, headers=headers, proxies=self.proxies,
#     272     timeout=self.requests_timeout, **args
#     273 )
# --> 275 response.raise_for_status()
#     276 results = response.json()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/search?q=&limit=10&offset=0&type=track
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# Cell In[103], line 2
#       1 song = input("Write your song: ")
# ----> 2 results = sp.search(q=song)
#       3 play_song(results["tracks"]["items"][0]["id"])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:602, in Spotify.search(self, q, limit, offset, type, market)
#     587 def search(self, q, limit=10, offset=0, type="track", market=None):
#     588     """ searches for an item
#     589
#     590         Parameters:
#    (...)
#     600                        from_token.
#     601     """
# --> 602     return self._get(
#     603         "search", q=q, limit=limit, offset=offset, type=type, market=market
#     604     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/spotipy/client.py:297, in Spotify._internal_call(self, method, url, payload, params)
#     290         reason = None
#     292     logger.error(
#     293         'HTTP Error for %s to %s with Params: %s returned %s due to %s',
#     294         method, url, args.get("params"), response.status_code, msg
#     295     )
# --> 297     raise SpotifyException(
#     298         response.status_code,
#     299         -1,
#     300         f"{response.url}:\n {msg}",
#     301         reason=reason,
#     302         headers=response.headers,
#     303     )
#     304 except requests.exceptions.RetryError as retry_error:
#     305     request = retry_error.request
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/search?q=&limit=10&offset=0&type=track:
#  No search query, reason: None

# %%
sp.audio_features(results["tracks"]["items"][0]["id"])
# Out:
# [{'danceability': 0.688,
#   'energy': 0.518,
#   'key': 5,
#   'loudness': -4.285,
#   'mode': 1,
#   'speechiness': 0.0283,
#   'acousticness': 0.0642,
#   'instrumentalness': 0,
#   'liveness': 0.1,
#   'valence': 0.314,
#   'tempo': 116.714,
#   'type': 'audio_features',
#   'id': '0W4NhJhcqKCqEP2GIpDCDq',
#   'uri': 'spotify:track:0W4NhJhcqKCqEP2GIpDCDq',
#   'track_href': 'https://api.spotify.com/v1/tracks/0W4NhJhcqKCqEP2GIpDCDq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0W4NhJhcqKCqEP2GIpDCDq',
#   'duration_ms': 255333,
#   'time_signature': 4}]

# %% [markdown]
# ## Extracting a song from playlist

# %%
playlist_id = "2wjdNzVqTL0tDyIaWJQVqG"
playlist = sp.user_playlist_tracks("spotify", playlist_id, market="GB")

# Liste der Songtitel in der Playlist anzeigen
for track in playlist['items']:
    print(track['track']['name'])
# Out:
# Murder On The Dancefloor
# Dog Days Are Over
# Say It Right
# Where Is The Love?
# Walking On A Dream
# So Sick
# You've Got The Love
# Just Dance
# Love
# Young Folks
# Bananza (Belly Dancer)
# Family Affair
# Drop It Like It's Hot
# Mr. Brightside
# Promiscuous
# Always On Time
# Because Of You
# Dynamite
# She Will Be Loved - Radio Mix
# Dangerous
# The Sweet Escape
# Umbrella
# Party In The U.S.A.
# The Real Slim Shady
# Empire State Of Mind
# I Kissed A Girl
# Dilemma
# It Wasn't Me
# Fergalicious
# A Thousand Miles
# Love Story (Taylor’s Version)
# Foolish
# Put Your Records On
# Naive
# Apologize
# Hey There Delilah
# Scar
# Bubbly
# Chasing Cars
# Stacy's Mom
# Bulletproof
# Grace Kelly
# I Miss You
# All The Things She Said
# This Ain't A Scene, It's An Arms Race
# Better Together
# Rehab
# Candy Shop
# Joker And The Thief
# Fireflies
# Whole Again
# Touch The Sky
# Breathless
# Unwritten
# Smack That
# Don't Cha
# Crank That (Soulja Boy)
# Let Me Blow Ya Mind
# Hanging By A Moment
# I Gotta Feeling
# Baby
# Luxurious
# This Love
# Pon de Replay
# Down
# Last Friday Night (T.G.I.F.)
# Glamorous
# I Don't Feel Like Dancin'
# Gold Digger
# Hero
# Beautiful Day
# In Da Club
# Hollaback Girl

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2wjdNzVqTL0tDyIaWJQVqG/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3WDbM110Rjj1ELU36QkQFr',
#      'id': '3WDbM110Rjj1ELU36QkQFr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27348fee203acc965735bb6e4ad',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0248fee203acc965735bb6e4ad',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485148fee203acc965735bb6e4ad',
#        'width': 64}],
#      'name': 'Read My Lips',
#      'release_date': '2002-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3WDbM110Rjj1ELU36QkQFr',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cBh5lVMg222FFuRU7EfDE'},
#        'href': 'https://api.spotify.com/v1/artists/2cBh5lVMg222FFuRU7EfDE',
#        'id': '2cBh5lVMg222FFuRU7EfDE',
#        'name': 'Sophie Ellis-Bextor',
#        'type': 'artist',
#        'uri': 'spotify:artist:2cBh5lVMg222FFuRU7EfDE'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3WDbM110Rjj1ELU36QkQFr'},
#      'total_tracks': 13},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cBh5lVMg222FFuRU7EfDE'},
#       'href': 'https://api.spotify.com/v1/artists/2cBh5lVMg222FFuRU7EfDE',
#       'id': '2cBh5lVMg222FFuRU7EfDE',
#       'name': 'Sophie Ellis-Bextor',
#       'type': 'artist',
#       'uri': 'spotify:artist:2cBh5lVMg222FFuRU7EfDE'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 230013,
#     'external_ids': {'isrc': 'GBAKW0100229'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ndXb2CwhrqtyHK6o6eVNd'},
#     'href': 'https://api.spotify.com/v1/tracks/0ndXb2CwhrqtyHK6o6eVNd',
#     'id': '4tKGFmENO69tZR9ahgZu48',
#     'name': 'Murder On The Dancefloor',
#     'popularity': 3,
#     'uri': 'spotify:track:4tKGFmENO69tZR9ahgZu48',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ndXb2CwhrqtyHK6o6eVNd'},
#      'href': 'https://api.spotify.com/v1/tracks/0ndXb2CwhrqtyHK6o6eVNd',
#      'id': '0ndXb2CwhrqtyHK6o6eVNd',
#      'type': 'track',
#      'uri': 'spotify:track:0ndXb2CwhrqtyHK6o6eVNd'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-05-07T22:53:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1rLLyY5p6HXNl2lKzINWp5',
#      'id': '1rLLyY5p6HXNl2lKzINWp5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273003f81b1f4246362638e682d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02003f81b1f4246362638e682d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851003f81b1f4246362638e682d',
#        'width': 64}],
#      'name': 'Lungs (Deluxe Version)',
#      'release_date': '2009',
#      'release_date_precision': 'year',
#      'uri': 'spotify:album:1rLLyY5p6HXNl2lKzINWp5',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#        'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#        'id': '1moxjboGR7GNWYIMWsRjgG',
#        'name': 'Florence + The Machine',
#        'type': 'artist',
#        'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rLLyY5p6HXNl2lKzINWp5'},
#      'total_tracks': 20},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#       'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#       'id': '1moxjboGR7GNWYIMWsRjgG',
#       'name': 'Florence + The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 252818,
#     'external_ids': {'isrc': 'GBUM70900209'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/456WNXWhDwYOSf5SpTuqxd'},
#     'href': 'https://api.spotify.com/v1/tracks/456WNXWhDwYOSf5SpTuqxd',
#     'id': '456WNXWhDwYOSf5SpTuqxd',
#     'name': 'Dog Days Are Over',
#     'popularity': 77,
#     'uri': 'spotify:track:456WNXWhDwYOSf5SpTuqxd',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2yboV2QBcVGEhcRlYuPpDT',
#      'id': '2yboV2QBcVGEhcRlYuPpDT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a6f439c8957170652f9410e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a6f439c8957170652f9410e2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a6f439c8957170652f9410e2',
#        'width': 64}],
#      'name': 'Loose',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2yboV2QBcVGEhcRlYuPpDT',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#        'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#        'id': '2jw70GZXlAI8QzWeY2bgRc',
#        'name': 'Nelly Furtado',
#        'type': 'artist',
#        'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2yboV2QBcVGEhcRlYuPpDT'},
#      'total_tracks': 17},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#       'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#       'id': '2jw70GZXlAI8QzWeY2bgRc',
#       'name': 'Nelly Furtado',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'}],
#     'disc_number': 1,
#     'track_number': 10,
#     'duration_ms': 223080,
#     'external_ids': {'isrc': 'USUM70603368'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2aI21FnmY7TJVKeMaoQZ0t'},
#     'href': 'https://api.spotify.com/v1/tracks/2aI21FnmY7TJVKeMaoQZ0t',
#     'id': '2aI21FnmY7TJVKeMaoQZ0t',
#     'name': 'Say It Right',
#     'popularity': 78,
#     'uri': 'spotify:track:2aI21FnmY7TJVKeMaoQZ0t',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/4wBDclsxFzGnR4kVAAMI7K',
#      'id': '4wBDclsxFzGnR4kVAAMI7K',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e435b4dfdcf5e3c4a25663df',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e435b4dfdcf5e3c4a25663df',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e435b4dfdcf5e3c4a25663df',
#        'width': 64}],
#      'name': 'Elephunk',
#      'release_date': '2003',
#      'release_date_precision': 'year',
#      'uri': 'spotify:album:4wBDclsxFzGnR4kVAAMI7K',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4wBDclsxFzGnR4kVAAMI7K'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'track_number': 13,
#     'duration_ms': 272533,
#     'external_ids': {'isrc': 'USIR10311862'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3CNqo3gYrfexdrtjFmC9he'},
#     'href': 'https://api.spotify.com/v1/tracks/3CNqo3gYrfexdrtjFmC9he',
#     'id': '0xmjwnQ3FNE6HuWCt2nHdZ',
#     'name': 'Where Is The Love?',
#     'popularity': 1,
#     'uri': 'spotify:track:0xmjwnQ3FNE6HuWCt2nHdZ',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3CNqo3gYrfexdrtjFmC9he'},
#      'href': 'https://api.spotify.com/v1/tracks/3CNqo3gYrfexdrtjFmC9he',
#      'id': '3CNqo3gYrfexdrtjFmC9he',
#      'type': 'track',
#      'uri': 'spotify:track:3CNqo3gYrfexdrtjFmC9he'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5B6XfyHHYawyLkEvNvhSPh',
#      'id': '5B6XfyHHYawyLkEvNvhSPh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f3aa0e6ca22a382007f61e4d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f3aa0e6ca22a382007f61e4d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f3aa0e6ca22a382007f61e4d',
#        'width': 64}],
#      'name': 'Walking On A Dream (10th Anniversary Edition)',
#      'release_date': '2008-10-03',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5B6XfyHHYawyLkEvNvhSPh',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67hb7towEyKvt5Z8Bx306c'},
#        'href': 'https://api.spotify.com/v1/artists/67hb7towEyKvt5Z8Bx306c',
#        'id': '67hb7towEyKvt5Z8Bx306c',
#        'name': 'Empire Of The Sun',
#        'type': 'artist',
#        'uri': 'spotify:artist:67hb7towEyKvt5Z8Bx306c'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5B6XfyHHYawyLkEvNvhSPh'},
#      'total_tracks': 16},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67hb7towEyKvt5Z8Bx306c'},
#       'href': 'https://api.spotify.com/v1/artists/67hb7towEyKvt5Z8Bx306c',
#       'id': '67hb7towEyKvt5Z8Bx306c',
#       'name': 'Empire Of The Sun',
#       'type': 'artist',
#       'uri': 'spotify:artist:67hb7towEyKvt5Z8Bx306c'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 198440,
#     'external_ids': {'isrc': 'AUEI10800039'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5r5cp9IpziiIsR6b93vcnQ'},
#     'href': 'https://api.spotify.com/v1/tracks/5r5cp9IpziiIsR6b93vcnQ',
#     'id': '5r5cp9IpziiIsR6b93vcnQ',
#     'name': 'Walking On A Dream',
#     'popularity': 79,
#     'uri': 'spotify:track:5r5cp9IpziiIsR6b93vcnQ',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6gkwOLmk0ALMOjWs5WhAEr',
#      'id': '6gkwOLmk0ALMOjWs5WhAEr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273987a1825341694ec9bc62457',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02987a1825341694ec9bc62457',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851987a1825341694ec9bc62457',
#        'width': 64}],
#      'name': 'In My Own Words',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6gkwOLmk0ALMOjWs5WhAEr',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#        'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#        'id': '21E3waRsmPlU7jZsS13rcj',
#        'name': 'Ne-Yo',
#        'type': 'artist',
#        'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6gkwOLmk0ALMOjWs5WhAEr'},
#      'total_tracks': 13},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#       'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#       'id': '21E3waRsmPlU7jZsS13rcj',
#       'name': 'Ne-Yo',
#       'type': 'artist',
#       'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 207186,
#     'external_ids': {'isrc': 'USUM70501633'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6brl7bwOHmGFkNw3MBqssT'},
#     'href': 'https://api.spotify.com/v1/tracks/6brl7bwOHmGFkNw3MBqssT',
#     'id': '5203pcq3cNteJuOVhIEnt6',
#     'name': 'So Sick',
#     'popularity': 78,
#     'uri': 'spotify:track:5203pcq3cNteJuOVhIEnt6',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6brl7bwOHmGFkNw3MBqssT'},
#      'href': 'https://api.spotify.com/v1/tracks/6brl7bwOHmGFkNw3MBqssT',
#      'id': '6brl7bwOHmGFkNw3MBqssT',
#      'type': 'track',
#      'uri': 'spotify:track:6brl7bwOHmGFkNw3MBqssT'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1rLLyY5p6HXNl2lKzINWp5',
#      'id': '1rLLyY5p6HXNl2lKzINWp5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273003f81b1f4246362638e682d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02003f81b1f4246362638e682d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851003f81b1f4246362638e682d',
#        'width': 64}],
#      'name': 'Lungs (Deluxe Version)',
#      'release_date': '2009',
#      'release_date_precision': 'year',
#      'uri': 'spotify:album:1rLLyY5p6HXNl2lKzINWp5',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#        'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#        'id': '1moxjboGR7GNWYIMWsRjgG',
#        'name': 'Florence + The Machine',
#        'type': 'artist',
#        'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rLLyY5p6HXNl2lKzINWp5'},
#      'total_tracks': 20},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#       'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#       'id': '1moxjboGR7GNWYIMWsRjgG',
#       'name': 'Florence + The Machine',
#       'type': 'artist',
#       'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#     'disc_number': 1,
#     'track_number': 13,
#     'duration_ms': 168666,
#     'external_ids': {'isrc': 'GBUM70900237'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/244AvzGQ4Ksa5637JQu5Gy'},
#     'href': 'https://api.spotify.com/v1/tracks/244AvzGQ4Ksa5637JQu5Gy',
#     'id': '244AvzGQ4Ksa5637JQu5Gy',
#     'name': "You've Got The Love",
#     'popularity': 76,
#     'uri': 'spotify:track:244AvzGQ4Ksa5637JQu5Gy',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/1qwlxZTNLe1jq3b0iidlue',
#      'id': '1qwlxZTNLe1jq3b0iidlue',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e691217483df8798445c82e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e691217483df8798445c82e2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e691217483df8798445c82e2',
#        'width': 64}],
#      'name': 'The Fame',
#      'release_date': '2008-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:1qwlxZTNLe1jq3b0iidlue',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1qwlxZTNLe1jq3b0iidlue'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fObcBw9VM3x7ntWKCYl0z'},
#       'href': 'https://api.spotify.com/v1/artists/7fObcBw9VM3x7ntWKCYl0z',
#       'id': '7fObcBw9VM3x7ntWKCYl0z',
#       'name': "Colby O'Donis",
#       'type': 'artist',
#       'uri': 'spotify:artist:7fObcBw9VM3x7ntWKCYl0z'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 241933,
#     'external_ids': {'isrc': 'USUM70807646'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1dzQoRqT5ucxXVaAhTcT0J'},
#     'href': 'https://api.spotify.com/v1/tracks/1dzQoRqT5ucxXVaAhTcT0J',
#     'id': '1dzQoRqT5ucxXVaAhTcT0J',
#     'name': 'Just Dance',
#     'popularity': 79,
#     'uri': 'spotify:track:1dzQoRqT5ucxXVaAhTcT0J',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-15T22:00:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/4zEAsP0RIfbGARdtsgAaUV',
#      'id': '4zEAsP0RIfbGARdtsgAaUV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732cc2323c681b3f84cdc8379a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022cc2323c681b3f84cdc8379a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512cc2323c681b3f84cdc8379a',
#        'width': 64}],
#      'name': 'The Way It Is',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4zEAsP0RIfbGARdtsgAaUV',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vfezMIyCr4XUdYRaKIKi3'},
#        'href': 'https://api.spotify.com/v1/artists/1vfezMIyCr4XUdYRaKIKi3',
#        'id': '1vfezMIyCr4XUdYRaKIKi3',
#        'name': 'Keyshia Cole',
#        'type': 'artist',
#        'uri': 'spotify:artist:1vfezMIyCr4XUdYRaKIKi3'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4zEAsP0RIfbGARdtsgAaUV'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vfezMIyCr4XUdYRaKIKi3'},
#       'href': 'https://api.spotify.com/v1/artists/1vfezMIyCr4XUdYRaKIKi3',
#       'id': '1vfezMIyCr4XUdYRaKIKi3',
#       'name': 'Keyshia Cole',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vfezMIyCr4XUdYRaKIKi3'}],
#     'disc_number': 1,
#     'track_number': 6,
#     'duration_ms': 255333,
#     'external_ids': {'isrc': 'USAM10500210'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0W4NhJhcqKCqEP2GIpDCDq'},
#     'href': 'https://api.spotify.com/v1/tracks/0W4NhJhcqKCqEP2GIpDCDq',
#     'id': '0W4NhJhcqKCqEP2GIpDCDq',
#     'name': 'Love',
#     'popularity': 80,
#     'uri': 'spotify:track:0W4NhJhcqKCqEP2GIpDCDq',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-10-31T02:06:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5g4E06cxsFEMFE9hSekAt2',
#      'id': '5g4E06cxsFEMFE9hSekAt2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739cf4ac84b224a02f34d2e4f6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029cf4ac84b224a02f34d2e4f6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519cf4ac84b224a02f34d2e4f6',
#        'width': 64}],
#      'name': "Writer's Block",
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5g4E06cxsFEMFE9hSekAt2',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6u11Qbko2N2hP4lTBYjX86'},
#        'href': 'https://api.spotify.com/v1/artists/6u11Qbko2N2hP4lTBYjX86',
#        'id': '6u11Qbko2N2hP4lTBYjX86',
#        'name': 'Peter Bjorn and John',
#        'type': 'artist',
#        'uri': 'spotify:artist:6u11Qbko2N2hP4lTBYjX86'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5g4E06cxsFEMFE9hSekAt2'},
#      'total_tracks': 11},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6u11Qbko2N2hP4lTBYjX86'},
#       'href': 'https://api.spotify.com/v1/artists/6u11Qbko2N2hP4lTBYjX86',
#       'id': '6u11Qbko2N2hP4lTBYjX86',
#       'name': 'Peter Bjorn and John',
#       'type': 'artist',
#       'uri': 'spotify:artist:6u11Qbko2N2hP4lTBYjX86'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 276693,
#     'external_ids': {'isrc': 'SEBPA0600024'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4dyx5SzxPPaD8xQIid5Wjj'},
#     'href': 'https://api.spotify.com/v1/tracks/4dyx5SzxPPaD8xQIid5Wjj',
#     'id': '4dyx5SzxPPaD8xQIid5Wjj',
#     'name': 'Young Folks',
#     'popularity': 76,
#     'uri': 'spotify:track:4dyx5SzxPPaD8xQIid5Wjj',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6rlTdXLpnOufwfL0SbWLDf',
#      'id': '6rlTdXLpnOufwfL0SbWLDf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c45a75cba7099003063c8e64',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c45a75cba7099003063c8e64',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c45a75cba7099003063c8e64',
#        'width': 64}],
#      'name': 'Trouble',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6rlTdXLpnOufwfL0SbWLDf',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0z4gvV4rjIZ9wHck67ucSV'},
#        'href': 'https://api.spotify.com/v1/artists/0z4gvV4rjIZ9wHck67ucSV',
#        'id': '0z4gvV4rjIZ9wHck67ucSV',
#        'name': 'Akon',
#        'type': 'artist',
#        'uri': 'spotify:artist:0z4gvV4rjIZ9wHck67ucSV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6rlTdXLpnOufwfL0SbWLDf'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0z4gvV4rjIZ9wHck67ucSV'},
#       'href': 'https://api.spotify.com/v1/artists/0z4gvV4rjIZ9wHck67ucSV',
#       'id': '0z4gvV4rjIZ9wHck67ucSV',
#       'name': 'Akon',
#       'type': 'artist',
#       'uri': 'spotify:artist:0z4gvV4rjIZ9wHck67ucSV'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 238493,
#     'external_ids': {'isrc': 'USUR10300501'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0dNPpDFdvzj6XFIRzg2hmp'},
#     'href': 'https://api.spotify.com/v1/tracks/0dNPpDFdvzj6XFIRzg2hmp',
#     'id': '3BwkldhE22DdxOcXegF2Kv',
#     'name': 'Bananza (Belly Dancer)',
#     'popularity': 0,
#     'uri': 'spotify:track:3BwkldhE22DdxOcXegF2Kv',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0dNPpDFdvzj6XFIRzg2hmp'},
#      'href': 'https://api.spotify.com/v1/tracks/0dNPpDFdvzj6XFIRzg2hmp',
#      'id': '0dNPpDFdvzj6XFIRzg2hmp',
#      'type': 'track',
#      'uri': 'spotify:track:0dNPpDFdvzj6XFIRzg2hmp'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5QJmKwPveBV4IwLlo4OcG4',
#      'id': '5QJmKwPveBV4IwLlo4OcG4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273096a7fc9668305db9d3175fc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02096a7fc9668305db9d3175fc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851096a7fc9668305db9d3175fc',
#        'width': 64}],
#      'name': 'No More Drama',
#      'release_date': '2001-08-28',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5QJmKwPveBV4IwLlo4OcG4',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1XkoF8ryArs86LZvFOkbyr'},
#        'href': 'https://api.spotify.com/v1/artists/1XkoF8ryArs86LZvFOkbyr',
#        'id': '1XkoF8ryArs86LZvFOkbyr',
#        'name': 'Mary J. Blige',
#        'type': 'artist',
#        'uri': 'spotify:artist:1XkoF8ryArs86LZvFOkbyr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5QJmKwPveBV4IwLlo4OcG4'},
#      'total_tracks': 17},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1XkoF8ryArs86LZvFOkbyr'},
#       'href': 'https://api.spotify.com/v1/artists/1XkoF8ryArs86LZvFOkbyr',
#       'id': '1XkoF8ryArs86LZvFOkbyr',
#       'name': 'Mary J. Blige',
#       'type': 'artist',
#       'uri': 'spotify:artist:1XkoF8ryArs86LZvFOkbyr'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 265866,
#     'external_ids': {'isrc': 'USMC10111369'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3aw9iWUQ3VrPQltgwvN9Xu'},
#     'href': 'https://api.spotify.com/v1/tracks/3aw9iWUQ3VrPQltgwvN9Xu',
#     'id': '3aw9iWUQ3VrPQltgwvN9Xu',
#     'name': 'Family Affair',
#     'popularity': 78,
#     'uri': 'spotify:track:3aw9iWUQ3VrPQltgwvN9Xu',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6cpp6a0RDlZhHUa2C1ArN3',
#      'id': '6cpp6a0RDlZhHUa2C1ArN3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d2d885c08daccf13c6c304ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d2d885c08daccf13c6c304ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d2d885c08daccf13c6c304ce',
#        'width': 64}],
#      'name': 'R&G (Rhythm & Gangsta): The Masterpiece',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6cpp6a0RDlZhHUa2C1ArN3',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hJcb9fa4alzcOq3EaNPoG'},
#        'href': 'https://api.spotify.com/v1/artists/7hJcb9fa4alzcOq3EaNPoG',
#        'id': '7hJcb9fa4alzcOq3EaNPoG',
#        'name': 'Snoop Dogg',
#        'type': 'artist',
#        'uri': 'spotify:artist:7hJcb9fa4alzcOq3EaNPoG'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6cpp6a0RDlZhHUa2C1ArN3'},
#      'total_tracks': 20},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7hJcb9fa4alzcOq3EaNPoG'},
#       'href': 'https://api.spotify.com/v1/artists/7hJcb9fa4alzcOq3EaNPoG',
#       'id': '7hJcb9fa4alzcOq3EaNPoG',
#       'name': 'Snoop Dogg',
#       'type': 'artist',
#       'uri': 'spotify:artist:7hJcb9fa4alzcOq3EaNPoG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2RdwBSPQiwcmiDo9kixcl8'},
#       'href': 'https://api.spotify.com/v1/artists/2RdwBSPQiwcmiDo9kixcl8',
#       'id': '2RdwBSPQiwcmiDo9kixcl8',
#       'name': 'Pharrell Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:2RdwBSPQiwcmiDo9kixcl8'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 266066,
#     'external_ids': {'isrc': 'USMC10400640'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/70ludZZEUJy1aFVkPI0Kpi'},
#     'href': 'https://api.spotify.com/v1/tracks/70ludZZEUJy1aFVkPI0Kpi',
#     'id': '2NBQmPrOEEjA8VbeWOQGxO',
#     'name': "Drop It Like It's Hot",
#     'popularity': 1,
#     'uri': 'spotify:track:2NBQmPrOEEjA8VbeWOQGxO',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/70ludZZEUJy1aFVkPI0Kpi'},
#      'href': 'https://api.spotify.com/v1/tracks/70ludZZEUJy1aFVkPI0Kpi',
#      'id': '70ludZZEUJy1aFVkPI0Kpi',
#      'type': 'track',
#      'uri': 'spotify:track:70ludZZEUJy1aFVkPI0Kpi'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/6TJmQnO44YE5BtTxH8pop1',
#      'id': '6TJmQnO44YE5BtTxH8pop1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273797febe9f06dd027b67a3e64',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02797febe9f06dd027b67a3e64',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851797febe9f06dd027b67a3e64',
#        'width': 64}],
#      'name': 'Hot Fuss',
#      'release_date': '2004-06-15',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6TJmQnO44YE5BtTxH8pop1',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#        'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#        'id': '0C0XlULifJtAgn6ZNCW2eu',
#        'name': 'The Killers',
#        'type': 'artist',
#        'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6TJmQnO44YE5BtTxH8pop1'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C0XlULifJtAgn6ZNCW2eu'},
#       'href': 'https://api.spotify.com/v1/artists/0C0XlULifJtAgn6ZNCW2eu',
#       'id': '0C0XlULifJtAgn6ZNCW2eu',
#       'name': 'The Killers',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C0XlULifJtAgn6ZNCW2eu'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 222075,
#     'external_ids': {'isrc': 'USIR20400274'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0eGsygTp906u18L0Oimnem'},
#     'href': 'https://api.spotify.com/v1/tracks/0eGsygTp906u18L0Oimnem',
#     'id': '003vvx7Niy0yvhvHt4a68B',
#     'name': 'Mr. Brightside',
#     'popularity': 1,
#     'uri': 'spotify:track:003vvx7Niy0yvhvHt4a68B',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0eGsygTp906u18L0Oimnem'},
#      'href': 'https://api.spotify.com/v1/tracks/0eGsygTp906u18L0Oimnem',
#      'id': '0eGsygTp906u18L0Oimnem',
#      'type': 'track',
#      'uri': 'spotify:track:0eGsygTp906u18L0Oimnem'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2yboV2QBcVGEhcRlYuPpDT',
#      'id': '2yboV2QBcVGEhcRlYuPpDT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a6f439c8957170652f9410e2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a6f439c8957170652f9410e2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a6f439c8957170652f9410e2',
#        'width': 64}],
#      'name': 'Loose',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2yboV2QBcVGEhcRlYuPpDT',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#        'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#        'id': '2jw70GZXlAI8QzWeY2bgRc',
#        'name': 'Nelly Furtado',
#        'type': 'artist',
#        'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2yboV2QBcVGEhcRlYuPpDT'},
#      'total_tracks': 17},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#       'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#       'id': '2jw70GZXlAI8QzWeY2bgRc',
#       'name': 'Nelly Furtado',
#       'type': 'artist',
#       'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Y5TRrQiqgUO4S36tzjIRZ'},
#       'href': 'https://api.spotify.com/v1/artists/5Y5TRrQiqgUO4S36tzjIRZ',
#       'id': '5Y5TRrQiqgUO4S36tzjIRZ',
#       'name': 'Timbaland',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Y5TRrQiqgUO4S36tzjIRZ'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 242293,
#     'external_ids': {'isrc': 'USUM70603473'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2gam98EZKrF9XuOkU13ApN'},
#     'href': 'https://api.spotify.com/v1/tracks/2gam98EZKrF9XuOkU13ApN',
#     'id': '2gam98EZKrF9XuOkU13ApN',
#     'name': 'Promiscuous',
#     'popularity': 82,
#     'uri': 'spotify:track:2gam98EZKrF9XuOkU13ApN',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/2wMavIKnu6feFNOeQ1hVwf',
#      'id': '2wMavIKnu6feFNOeQ1hVwf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e37dce36d17a97c3011d1068',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e37dce36d17a97c3011d1068',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e37dce36d17a97c3011d1068',
#        'width': 64}],
#      'name': 'Pain Is Love',
#      'release_date': '2001-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:2wMavIKnu6feFNOeQ1hVwf',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1J2VVASYAamtQ3Bt8wGgA6'},
#        'href': 'https://api.spotify.com/v1/artists/1J2VVASYAamtQ3Bt8wGgA6',
#        'id': '1J2VVASYAamtQ3Bt8wGgA6',
#        'name': 'Ja Rule',
#        'type': 'artist',
#        'uri': 'spotify:artist:1J2VVASYAamtQ3Bt8wGgA6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2wMavIKnu6feFNOeQ1hVwf'},
#      'total_tracks': 16},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1J2VVASYAamtQ3Bt8wGgA6'},
#       'href': 'https://api.spotify.com/v1/artists/1J2VVASYAamtQ3Bt8wGgA6',
#       'id': '1J2VVASYAamtQ3Bt8wGgA6',
#       'name': 'Ja Rule',
#       'type': 'artist',
#       'uri': 'spotify:artist:1J2VVASYAamtQ3Bt8wGgA6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5rkVyNGXEgeUqKkB5ccK83'},
#       'href': 'https://api.spotify.com/v1/artists/5rkVyNGXEgeUqKkB5ccK83',
#       'id': '5rkVyNGXEgeUqKkB5ccK83',
#       'name': 'Ashanti',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rkVyNGXEgeUqKkB5ccK83'}],
#     'disc_number': 1,
#     'track_number': 5,
#     'duration_ms': 245133,
#     'external_ids': {'isrc': 'USDJ20110760'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4hrae8atte6cRlSC9a7VCO'},
#     'href': 'https://api.spotify.com/v1/tracks/4hrae8atte6cRlSC9a7VCO',
#     'id': '2hNf1rawV2XAZ6Jld2Fxwf',
#     'name': 'Always On Time',
#     'popularity': 3,
#     'uri': 'spotify:track:2hNf1rawV2XAZ6Jld2Fxwf',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4hrae8atte6cRlSC9a7VCO'},
#      'href': 'https://api.spotify.com/v1/tracks/4hrae8atte6cRlSC9a7VCO',
#      'id': '4hrae8atte6cRlSC9a7VCO',
#      'type': 'track',
#      'uri': 'spotify:track:4hrae8atte6cRlSC9a7VCO'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/52q9xNv8COtSU9phlbO5sg',
#      'id': '52q9xNv8COtSU9phlbO5sg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ec4f8c81eb9ddee00e01798d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ec4f8c81eb9ddee00e01798d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ec4f8c81eb9ddee00e01798d',
#        'width': 64}],
#      'name': 'Because Of You',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:52q9xNv8COtSU9phlbO5sg',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#        'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#        'id': '21E3waRsmPlU7jZsS13rcj',
#        'name': 'Ne-Yo',
#        'type': 'artist',
#        'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/52q9xNv8COtSU9phlbO5sg'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#       'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#       'id': '21E3waRsmPlU7jZsS13rcj',
#       'name': 'Ne-Yo',
#       'type': 'artist',
#       'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 266840,
#     'external_ids': {'isrc': 'USUM70731570'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6CFPFnS9EcLs2I0nWqtWci'},
#     'href': 'https://api.spotify.com/v1/tracks/6CFPFnS9EcLs2I0nWqtWci',
#     'id': '2VarpyoSpCPNKI56WSAEMN',
#     'name': 'Because Of You',
#     'popularity': 75,
#     'uri': 'spotify:track:2VarpyoSpCPNKI56WSAEMN',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6CFPFnS9EcLs2I0nWqtWci'},
#      'href': 'https://api.spotify.com/v1/tracks/6CFPFnS9EcLs2I0nWqtWci',
#      'id': '6CFPFnS9EcLs2I0nWqtWci',
#      'type': 'track',
#      'uri': 'spotify:track:6CFPFnS9EcLs2I0nWqtWci'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'compilation',
#      'href': 'https://api.spotify.com/v1/albums/0eGvq1J5Ke7VlLLOYIlY4k',
#      'id': '0eGvq1J5Ke7VlLLOYIlY4k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366c3eb32692a0ae487079cf1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266c3eb32692a0ae487079cf1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166c3eb32692a0ae487079cf1',
#        'width': 64}],
#      'name': 'The Rokstarr Hits Collection',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:0eGvq1J5Ke7VlLLOYIlY4k',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#        'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#        'id': '6MF9fzBmfXghAz953czmBC',
#        'name': 'Taio Cruz',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0eGvq1J5Ke7VlLLOYIlY4k'},
#      'total_tracks': 15},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#       'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#       'id': '6MF9fzBmfXghAz953czmBC',
#       'name': 'Taio Cruz',
# ...
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3YIdZQ7UbWoTxPgznAYVOC',
#      'id': '3YIdZQ7UbWoTxPgznAYVOC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ab41b12bbc0f61ebdfb2dfaf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ab41b12bbc0f61ebdfb2dfaf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ab41b12bbc0f61ebdfb2dfaf',
#        'width': 64}],
#      'name': 'Ta Dah',
#      'release_date': '2006-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3YIdZQ7UbWoTxPgznAYVOC',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y10boYzeuFCJ4Qgp53w6o'},
#        'href': 'https://api.spotify.com/v1/artists/3Y10boYzeuFCJ4Qgp53w6o',
#        'id': '3Y10boYzeuFCJ4Qgp53w6o',
#        'name': 'Scissor Sisters',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Y10boYzeuFCJ4Qgp53w6o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3YIdZQ7UbWoTxPgznAYVOC'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Y10boYzeuFCJ4Qgp53w6o'},
#       'href': 'https://api.spotify.com/v1/artists/3Y10boYzeuFCJ4Qgp53w6o',
#       'id': '3Y10boYzeuFCJ4Qgp53w6o',
#       'name': 'Scissor Sisters',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Y10boYzeuFCJ4Qgp53w6o'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 288360,
#     'external_ids': {'isrc': 'GBUM70602587'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/13pyGLYmBjYgvOMIEivX2K'},
#     'href': 'https://api.spotify.com/v1/tracks/13pyGLYmBjYgvOMIEivX2K',
#     'id': '1q9l6c8bAzqWcvO3DM6FsR',
#     'name': "I Don't Feel Like Dancin'",
#     'popularity': 54,
#     'uri': 'spotify:track:1q9l6c8bAzqWcvO3DM6FsR',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/13pyGLYmBjYgvOMIEivX2K'},
#      'href': 'https://api.spotify.com/v1/tracks/13pyGLYmBjYgvOMIEivX2K',
#      'id': '13pyGLYmBjYgvOMIEivX2K',
#      'type': 'track',
#      'uri': 'spotify:track:13pyGLYmBjYgvOMIEivX2K'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5ll74bqtkcXlKE7wwkMq4g',
#      'id': '5ll74bqtkcXlKE7wwkMq4g',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273428d2255141c2119409a31b2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02428d2255141c2119409a31b2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851428d2255141c2119409a31b2',
#        'width': 64}],
#      'name': 'Late Registration',
#      'release_date': '2005-08-30',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5ll74bqtkcXlKE7wwkMq4g',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#        'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#        'id': '5K4W6rqBFWDnAN6FQUkS6x',
#        'name': 'Kanye West',
#        'type': 'artist',
#        'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ll74bqtkcXlKE7wwkMq4g'},
#      'total_tracks': 21},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7LnaAXbDVIL75IVPnndf7w'},
#       'href': 'https://api.spotify.com/v1/artists/7LnaAXbDVIL75IVPnndf7w',
#       'id': '7LnaAXbDVIL75IVPnndf7w',
#       'name': 'Jamie Foxx',
#       'type': 'artist',
#       'uri': 'spotify:artist:7LnaAXbDVIL75IVPnndf7w'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 207626,
#     'external_ids': {'isrc': 'USUM70500143'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1PS1QMdUqOal0ai3Gt7sDQ'},
#     'href': 'https://api.spotify.com/v1/tracks/1PS1QMdUqOal0ai3Gt7sDQ',
#     'id': '3QHPHLAkYV5cQBUYs6rowx',
#     'name': 'Gold Digger',
#     'popularity': 79,
#     'uri': 'spotify:track:3QHPHLAkYV5cQBUYs6rowx',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1PS1QMdUqOal0ai3Gt7sDQ'},
#      'href': 'https://api.spotify.com/v1/tracks/1PS1QMdUqOal0ai3Gt7sDQ',
#      'id': '1PS1QMdUqOal0ai3Gt7sDQ',
#      'type': 'track',
#      'uri': 'spotify:track:1PS1QMdUqOal0ai3Gt7sDQ'}},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3DeHyfe2Da8xznvABSfIE5',
#      'id': '3DeHyfe2Da8xznvABSfIE5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27347527edce762c35fde07559c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0247527edce762c35fde07559c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485147527edce762c35fde07559c',
#        'width': 64}],
#      'name': 'Escape',
#      'release_date': '2001-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3DeHyfe2Da8xznvABSfIE5',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'},
#        'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw',
#        'id': '7qG3b048QCHVRO5Pv1T5lw',
#        'name': 'Enrique Iglesias',
#        'type': 'artist',
#        'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3DeHyfe2Da8xznvABSfIE5'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'},
#       'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw',
#       'id': '7qG3b048QCHVRO5Pv1T5lw',
#       'name': 'Enrique Iglesias',
#       'type': 'artist',
#       'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}],
#     'disc_number': 1,
#     'track_number': 4,
#     'duration_ms': 264240,
#     'external_ids': {'isrc': 'USIR10120047'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1PAgmT6YqGhd6zT9kN9gIo'},
#     'href': 'https://api.spotify.com/v1/tracks/1PAgmT6YqGhd6zT9kN9gIo',
#     'id': '1PAgmT6YqGhd6zT9kN9gIo',
#     'name': 'Hero',
#     'popularity': 65,
#     'uri': 'spotify:track:1PAgmT6YqGhd6zT9kN9gIo',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7a5U0GPoAvT3gvEY66FRuN',
#      'id': '7a5U0GPoAvT3gvEY66FRuN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27338fa0dfe55b1ff2e8c962bae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0238fa0dfe55b1ff2e8c962bae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485138fa0dfe55b1ff2e8c962bae',
#        'width': 64}],
#      'name': "All That You Can't Leave Behind",
#      'release_date': '2000-01-01',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7a5U0GPoAvT3gvEY66FRuN',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51Blml2LZPmy7TTiAg47vQ'},
#        'href': 'https://api.spotify.com/v1/artists/51Blml2LZPmy7TTiAg47vQ',
#        'id': '51Blml2LZPmy7TTiAg47vQ',
#        'name': 'U2',
#        'type': 'artist',
#        'uri': 'spotify:artist:51Blml2LZPmy7TTiAg47vQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7a5U0GPoAvT3gvEY66FRuN'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51Blml2LZPmy7TTiAg47vQ'},
#       'href': 'https://api.spotify.com/v1/artists/51Blml2LZPmy7TTiAg47vQ',
#       'id': '51Blml2LZPmy7TTiAg47vQ',
#       'name': 'U2',
#       'type': 'artist',
#       'uri': 'spotify:artist:51Blml2LZPmy7TTiAg47vQ'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 248400,
#     'external_ids': {'isrc': 'GBAAN0000196'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0gzqZ9d1jIKo9psEIthwXe'},
#     'href': 'https://api.spotify.com/v1/tracks/0gzqZ9d1jIKo9psEIthwXe',
#     'id': '0gzqZ9d1jIKo9psEIthwXe',
#     'name': 'Beautiful Day',
#     'popularity': 72,
#     'uri': 'spotify:track:0gzqZ9d1jIKo9psEIthwXe',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/5G5rgQHzdQnw32SI0WjIo5',
#      'id': '5G5rgQHzdQnw32SI0WjIo5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d843fabb75fef14010e30cae',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d843fabb75fef14010e30cae',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d843fabb75fef14010e30cae',
#        'width': 64}],
#      'name': "Get Rich Or Die Tryin'",
#      'release_date': '2003-02-06',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5G5rgQHzdQnw32SI0WjIo5',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3q7HBObVc0L8jNeTe5Gofh'},
#        'href': 'https://api.spotify.com/v1/artists/3q7HBObVc0L8jNeTe5Gofh',
#        'id': '3q7HBObVc0L8jNeTe5Gofh',
#        'name': '50 Cent',
#        'type': 'artist',
#        'uri': 'spotify:artist:3q7HBObVc0L8jNeTe5Gofh'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5G5rgQHzdQnw32SI0WjIo5'},
#      'total_tracks': 20},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3q7HBObVc0L8jNeTe5Gofh'},
#       'href': 'https://api.spotify.com/v1/artists/3q7HBObVc0L8jNeTe5Gofh',
#       'id': '3q7HBObVc0L8jNeTe5Gofh',
#       'name': '50 Cent',
#       'type': 'artist',
#       'uri': 'spotify:artist:3q7HBObVc0L8jNeTe5Gofh'}],
#     'disc_number': 1,
#     'track_number': 5,
#     'duration_ms': 193466,
#     'external_ids': {'isrc': 'USIR10300033'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7iL6o9tox1zgHpKUfh9vuC'},
#     'href': 'https://api.spotify.com/v1/tracks/7iL6o9tox1zgHpKUfh9vuC',
#     'id': '7iL6o9tox1zgHpKUfh9vuC',
#     'name': 'In Da Club',
#     'popularity': 81,
#     'uri': 'spotify:track:7iL6o9tox1zgHpKUfh9vuC',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2022-06-01T03:19:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#     'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#     'id': 'best-of-the-best',
#     'type': 'user',
#     'uri': 'spotify:user:best-of-the-best'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'is_playable': True,
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'is_playable': True,
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/34y7m68F7rN9ou6m5GWohR',
#      'id': '34y7m68F7rN9ou6m5GWohR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f049fc9322f0c93646cdcc77',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f049fc9322f0c93646cdcc77',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f049fc9322f0c93646cdcc77',
#        'width': 64}],
#      'name': 'Love Angel Music Baby',
#      'release_date': '2004-11-22',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:34y7m68F7rN9ou6m5GWohR',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#        'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#        'id': '4yiQZ8tQPux8cPriYMWUFP',
#        'name': 'Gwen Stefani',
#        'type': 'artist',
#        'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34y7m68F7rN9ou6m5GWohR'},
#      'total_tracks': 13},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#       'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#       'id': '4yiQZ8tQPux8cPriYMWUFP',
#       'name': 'Gwen Stefani',
#       'type': 'artist',
#       'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 199853,
#     'external_ids': {'isrc': 'USIR10400847'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0eqH0ALoDQevq59YcQ53KE'},
#     'href': 'https://api.spotify.com/v1/tracks/0eqH0ALoDQevq59YcQ53KE',
#     'id': '6KM6693N1wVvz6tDviEF4F',
#     'name': 'Hollaback Girl',
#     'popularity': 70,
#     'uri': 'spotify:track:6KM6693N1wVvz6tDviEF4F',
#     'is_local': False,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0eqH0ALoDQevq59YcQ53KE'},
#      'href': 'https://api.spotify.com/v1/tracks/0eqH0ALoDQevq59YcQ53KE',
#      'id': '0eqH0ALoDQevq59YcQ53KE',
#      'type': 'track',
#      'uri': 'spotify:track:0eqH0ALoDQevq59YcQ53KE'}},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 73}

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next".
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2wjdNzVqTL0tDyIaWJQVqG/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cBh5lVMg222FFuRU7EfDE'},
#                                              'href': 'https://api.spotify.com/v1/artists/2cBh5lVMg222FFuRU7EfDE',
#                                              'id': '2cBh5lVMg222FFuRU7EfDE',
#                                              'name': 'Sophie Ellis-Bextor',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2cBh5lVMg222FFuRU7EfDE'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3WDbM110Rjj1ELU36QkQFr'},
#                                 'href': 'https://api.spotify.com/v1/albums/3WDbM110Rjj1ELU36QkQFr',
#                                 'id': '3WDbM110Rjj1ELU36QkQFr',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27348fee203acc965735bb6e4ad',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0248fee203acc965735bb6e4ad',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485148fee203acc965735bb6e4ad',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Read My Lips',
#                                 'release_date': '2002-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3WDbM110Rjj1ELU36QkQFr'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cBh5lVMg222FFuRU7EfDE'},
#                                    'href': 'https://api.spotify.com/v1/artists/2cBh5lVMg222FFuRU7EfDE',
#                                    'id': '2cBh5lVMg222FFuRU7EfDE',
#                                    'name': 'Sophie Ellis-Bextor',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2cBh5lVMg222FFuRU7EfDE'}],
#                       'disc_number': 1,
#                       'duration_ms': 230013,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBAKW0100229'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0ndXb2CwhrqtyHK6o6eVNd'},
#                       'href': 'https://api.spotify.com/v1/tracks/0ndXb2CwhrqtyHK6o6eVNd',
#                       'id': '4tKGFmENO69tZR9ahgZu48',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0ndXb2CwhrqtyHK6o6eVNd'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0ndXb2CwhrqtyHK6o6eVNd',
#                                       'id': '0ndXb2CwhrqtyHK6o6eVNd',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0ndXb2CwhrqtyHK6o6eVNd'},
#                       'name': 'Murder On The Dancefloor',
#                       'popularity': 3,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:4tKGFmENO69tZR9ahgZu48'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-05-07T22:53:25Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#                                              'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#                                              'id': '1moxjboGR7GNWYIMWsRjgG',
#                                              'name': 'Florence + The Machine',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1rLLyY5p6HXNl2lKzINWp5'},
#                                 'href': 'https://api.spotify.com/v1/albums/1rLLyY5p6HXNl2lKzINWp5',
#                                 'id': '1rLLyY5p6HXNl2lKzINWp5',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273003f81b1f4246362638e682d',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02003f81b1f4246362638e682d',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851003f81b1f4246362638e682d',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Lungs (Deluxe Version)',
#                                 'release_date': '2009',
#                                 'release_date_precision': 'year',
#                                 'total_tracks': 20,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1rLLyY5p6HXNl2lKzINWp5'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#                                    'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#                                    'id': '1moxjboGR7GNWYIMWsRjgG',
#                                    'name': 'Florence + The Machine',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#                       'disc_number': 1,
#                       'duration_ms': 252818,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBUM70900209'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/456WNXWhDwYOSf5SpTuqxd'},
#                       'href': 'https://api.spotify.com/v1/tracks/456WNXWhDwYOSf5SpTuqxd',
#                       'id': '456WNXWhDwYOSf5SpTuqxd',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Dog Days Are Over',
#                       'popularity': 77,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:456WNXWhDwYOSf5SpTuqxd'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#                                              'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#                                              'id': '2jw70GZXlAI8QzWeY2bgRc',
#                                              'name': 'Nelly Furtado',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2yboV2QBcVGEhcRlYuPpDT'},
#                                 'href': 'https://api.spotify.com/v1/albums/2yboV2QBcVGEhcRlYuPpDT',
#                                 'id': '2yboV2QBcVGEhcRlYuPpDT',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a6f439c8957170652f9410e2',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a6f439c8957170652f9410e2',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a6f439c8957170652f9410e2',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Loose',
#                                 'release_date': '2006-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 17,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2yboV2QBcVGEhcRlYuPpDT'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jw70GZXlAI8QzWeY2bgRc'},
#                                    'href': 'https://api.spotify.com/v1/artists/2jw70GZXlAI8QzWeY2bgRc',
#                                    'id': '2jw70GZXlAI8QzWeY2bgRc',
#                                    'name': 'Nelly Furtado',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2jw70GZXlAI8QzWeY2bgRc'}],
#                       'disc_number': 1,
#                       'duration_ms': 223080,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUM70603368'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2aI21FnmY7TJVKeMaoQZ0t'},
#                       'href': 'https://api.spotify.com/v1/tracks/2aI21FnmY7TJVKeMaoQZ0t',
#                       'id': '2aI21FnmY7TJVKeMaoQZ0t',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Say It Right',
#                       'popularity': 78,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 10,
#                       'type': 'track',
#                       'uri': 'spotify:track:2aI21FnmY7TJVKeMaoQZ0t'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4wBDclsxFzGnR4kVAAMI7K'},
#                                 'href': 'https://api.spotify.com/v1/albums/4wBDclsxFzGnR4kVAAMI7K',
#                                 'id': '4wBDclsxFzGnR4kVAAMI7K',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273e435b4dfdcf5e3c4a25663df',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02e435b4dfdcf5e3c4a25663df',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851e435b4dfdcf5e3c4a25663df',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Elephunk',
#                                 'release_date': '2003',
#                                 'release_date_precision': 'year',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4wBDclsxFzGnR4kVAAMI7K'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 272533,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10311862'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3CNqo3gYrfexdrtjFmC9he'},
#                       'href': 'https://api.spotify.com/v1/tracks/3CNqo3gYrfexdrtjFmC9he',
#                       'id': '0xmjwnQ3FNE6HuWCt2nHdZ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3CNqo3gYrfexdrtjFmC9he'},
#                                       'href': 'https://api.spotify.com/v1/tracks/3CNqo3gYrfexdrtjFmC9he',
#                                       'id': '3CNqo3gYrfexdrtjFmC9he',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:3CNqo3gYrfexdrtjFmC9he'},
#                       'name': 'Where Is The Love?',
#                       'popularity': 1,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 13,
#                       'type': 'track',
#                       'uri': 'spotify:track:0xmjwnQ3FNE6HuWCt2nHdZ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67hb7towEyKvt5Z8Bx306c'},
#                                              'href': 'https://api.spotify.com/v1/artists/67hb7towEyKvt5Z8Bx306c',
#                                              'id': '67hb7towEyKvt5Z8Bx306c',
#                                              'name': 'Empire Of The Sun',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:67hb7towEyKvt5Z8Bx306c'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5B6XfyHHYawyLkEvNvhSPh'},
#                                 'href': 'https://api.spotify.com/v1/albums/5B6XfyHHYawyLkEvNvhSPh',
#                                 'id': '5B6XfyHHYawyLkEvNvhSPh',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273f3aa0e6ca22a382007f61e4d',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02f3aa0e6ca22a382007f61e4d',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851f3aa0e6ca22a382007f61e4d',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Walking On A Dream (10th Anniversary '
#                                         'Edition)',
#                                 'release_date': '2008-10-03',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5B6XfyHHYawyLkEvNvhSPh'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67hb7towEyKvt5Z8Bx306c'},
#                                    'href': 'https://api.spotify.com/v1/artists/67hb7towEyKvt5Z8Bx306c',
#                                    'id': '67hb7towEyKvt5Z8Bx306c',
#                                    'name': 'Empire Of The Sun',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:67hb7towEyKvt5Z8Bx306c'}],
#                       'disc_number': 1,
#                       'duration_ms': 198440,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'AUEI10800039'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5r5cp9IpziiIsR6b93vcnQ'},
#                       'href': 'https://api.spotify.com/v1/tracks/5r5cp9IpziiIsR6b93vcnQ',
#                       'id': '5r5cp9IpziiIsR6b93vcnQ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Walking On A Dream',
#                       'popularity': 79,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:5r5cp9IpziiIsR6b93vcnQ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#                                              'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#                                              'id': '21E3waRsmPlU7jZsS13rcj',
#                                              'name': 'Ne-Yo',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6gkwOLmk0ALMOjWs5WhAEr'},
#                                 'href': 'https://api.spotify.com/v1/albums/6gkwOLmk0ALMOjWs5WhAEr',
#                                 'id': '6gkwOLmk0ALMOjWs5WhAEr',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273987a1825341694ec9bc62457',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02987a1825341694ec9bc62457',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851987a1825341694ec9bc62457',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'In My Own Words',
#                                 'release_date': '2006-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6gkwOLmk0ALMOjWs5WhAEr'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21E3waRsmPlU7jZsS13rcj'},
#                                    'href': 'https://api.spotify.com/v1/artists/21E3waRsmPlU7jZsS13rcj',
#                                    'id': '21E3waRsmPlU7jZsS13rcj',
#                                    'name': 'Ne-Yo',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:21E3waRsmPlU7jZsS13rcj'}],
#                       'disc_number': 1,
#                       'duration_ms': 207186,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUM70501633'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6brl7bwOHmGFkNw3MBqssT'},
#                       'href': 'https://api.spotify.com/v1/tracks/6brl7bwOHmGFkNw3MBqssT',
#                       'id': '5203pcq3cNteJuOVhIEnt6',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6brl7bwOHmGFkNw3MBqssT'},
#                                       'href': 'https://api.spotify.com/v1/tracks/6brl7bwOHmGFkNw3MBqssT',
#                                       'id': '6brl7bwOHmGFkNw3MBqssT',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:6brl7bwOHmGFkNw3MBqssT'},
#                       'name': 'So Sick',
#                       'popularity': 78,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:5203pcq3cNteJuOVhIEnt6'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#                                              'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#                                              'id': '1moxjboGR7GNWYIMWsRjgG',
#                                              'name': 'Florence + The Machine',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1rLLyY5p6HXNl2lKzINWp5'},
#                                 'href': 'https://api.spotify.com/v1/albums/1rLLyY5p6HXNl2lKzINWp5',
#                                 'id': '1rLLyY5p6HXNl2lKzINWp5',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273003f81b1f4246362638e682d',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02003f81b1f4246362638e682d',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851003f81b1f4246362638e682d',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Lungs (Deluxe Version)',
#                                 'release_date': '2009',
#                                 'release_date_precision': 'year',
#                                 'total_tracks': 20,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1rLLyY5p6HXNl2lKzINWp5'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1moxjboGR7GNWYIMWsRjgG'},
#                                    'href': 'https://api.spotify.com/v1/artists/1moxjboGR7GNWYIMWsRjgG',
#                                    'id': '1moxjboGR7GNWYIMWsRjgG',
#                                    'name': 'Florence + The Machine',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1moxjboGR7GNWYIMWsRjgG'}],
#                       'disc_number': 1,
#                       'duration_ms': 168666,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBUM70900237'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/244AvzGQ4Ksa5637JQu5Gy'},
#                       'href': 'https://api.spotify.com/v1/tracks/244AvzGQ4Ksa5637JQu5Gy',
#                       'id': '244AvzGQ4Ksa5637JQu5Gy',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': "You've Got The Love",
#                       'popularity': 76,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 13,
#                       'type': 'track',
#                       'uri': 'spotify:track:244AvzGQ4Ksa5637JQu5Gy'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#                                              'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#                                              'id': '1HY2Jd0NmPuamShAr6KMms',
#                                              'name': 'Lady Gaga',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1qwlxZTNLe1jq3b0iidlue'},
#                                 'href': 'https://api.spotify.com/v1/albums/1qwlxZTNLe1jq3b0iidlue',
#                                 'id': '1qwlxZTNLe1jq3b0iidlue',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273e691217483df8798445c82e2',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02e691217483df8798445c82e2',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851e691217483df8798445c82e2',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'The Fame',
#                                 'release_date': '2008-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1qwlxZTNLe1jq3b0iidlue'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#                                    'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#                                    'id': '1HY2Jd0NmPuamShAr6KMms',
#                                    'name': 'Lady Gaga',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fObcBw9VM3x7ntWKCYl0z'},
#                                    'href': 'https://api.spotify.com/v1/artists/7fObcBw9VM3x7ntWKCYl0z',
#                                    'id': '7fObcBw9VM3x7ntWKCYl0z',
#                                    'name': "Colby O'Donis",
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7fObcBw9VM3x7ntWKCYl0z'}],
#                       'disc_number': 1,
#                       'duration_ms': 241933,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUM70807646'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1dzQoRqT5ucxXVaAhTcT0J'},
#                       'href': 'https://api.spotify.com/v1/tracks/1dzQoRqT5ucxXVaAhTcT0J',
#                       'id': '1dzQoRqT5ucxXVaAhTcT0J',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Just Dance',
#                       'popularity': 79,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:1dzQoRqT5ucxXVaAhTcT0J'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-10-15T22:00:38Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vfezMIyCr4XUdYRaKIKi3'},
#                                              'href': 'https://api.spotify.com/v1/artists/1vfezMIyCr4XUdYRaKIKi3',
#                                              'id': '1vfezMIyCr4XUdYRaKIKi3',
#                                              'name': 'Keyshia Cole',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1vfezMIyCr4XUdYRaKIKi3'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4zEAsP0RIfbGARdtsgAaUV'},
#                                 'href': 'https://api.spotify.com/v1/albums/4zEAsP0RIfbGARdtsgAaUV',
#                                 'id': '4zEAsP0RIfbGARdtsgAaUV',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732cc2323c681b3f84cdc8379a',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022cc2323c681b3f84cdc8379a',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512cc2323c681b3f84cdc8379a',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'The Way It Is',
#                                 'release_date': '2005-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4zEAsP0RIfbGARdtsgAaUV'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vfezMIyCr4XUdYRaKIKi3'},
#                                    'href': 'https://api.spotify.com/v1/artists/1vfezMIyCr4XUdYRaKIKi3',
#                                    'id': '1vfezMIyCr4XUdYRaKIKi3',
#                                    'name': 'Keyshia Cole',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1vfezMIyCr4XUdYRaKIKi3'}],
#                       'disc_number': 1,
#                       'duration_ms': 255333,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USAM10500210'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0W4NhJhcqKCqEP2GIpDCDq'},
#                       'href': 'https://api.spotify.com/v1/tracks/0W4NhJhcqKCqEP2GIpDCDq',
#                       'id': '0W4NhJhcqKCqEP2GIpDCDq',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Love',
#                       'popularity': 80,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 6,
#                       'type': 'track',
#                       'uri': 'spotify:track:0W4NhJhcqKCqEP2GIpDCDq'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-10-31T02:06:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6u11Qbko2N2hP4lTBYjX86'},
#                                              'href': 'https://api.spotify.com/v1/artists/6u11Qbko2N2hP4lTBYjX86',
#                                              'id': '6u11Qbko2N2hP4lTBYjX86',
#                                              'name': 'Peter Bjorn and John',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:6u11Qbko2N2hP4lTBYjX86'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5g4E06cxsFEMFE9hSekAt2'},
#                                 'href': 'https://api.spotify.com/v1/albums/5g4E06cxsFEMFE9hSekAt2',
#                                 'id': '5g4E06cxsFEMFE9hSekAt2',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2739cf4ac84b224a02f34d2e4f6',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e029cf4ac84b224a02f34d2e4f6',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048519cf4ac84b224a02f34d2e4f6',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': "Writer's Block",
#                                 'release_date': '2006-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 11,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5g4E06cxsFEMFE9hSekAt2'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6u11Qbko2N2hP4lTBYjX86'},
#                                    'href': 'https://api.spotify.com/v1/artists/6u11Qbko2N2hP4lTBYjX86',
#                                    'id': '6u11Qbko2N2hP4lTBYjX86',
#                                    'name': 'Peter Bjorn and John',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:6u11Qbko2N2hP4lTBYjX86'}],
#                       'disc_number': 1,
#                       'duration_ms': 276693,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'SEBPA0600024'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4dyx5SzxPPaD8xQIid5Wjj'},
#                       'href': 'https://api.spotify.com/v1/tracks/4dyx5SzxPPaD8xQIid5Wjj',
#                       'id': '4dyx5SzxPPaD8xQIid5Wjj',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Young Folks',
#                       'popularity': 76,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:4dyx5SzxPPaD8xQIid5Wjj'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0z4gvV4rjIZ9wHck67ucSV'},
#                                              'href': 'https://api.spotify.com/v1/artists/0z4gvV4rjIZ9wHck67ucSV',
#                                              'id': '0z4gvV4rjIZ9wHck67ucSV',
#                                              'name': 'Akon',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0z4gvV4rjIZ9wHck67ucSV'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6rlTdXLpnOufwfL0SbWLDf'},
#                                 'href': 'https://api.spotify.com/v1/albums/6rlTdXLpnOufwfL0SbWLDf',
#                                 'id': '6rlTdXLpnOufwfL0SbWLDf',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c45a75cba7099003063c8e64',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c45a75cba7099003063c8e64',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c45a75cba7099003063c8e64',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Trouble',
#                                 'release_date': '2004-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6rlTdXLpnOufwfL0SbWLDf'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0z4gvV4rjIZ9wHck67ucSV'},
#                                    'href': 'https://api.spotify.com/v1/artists/0z4gvV4rjIZ9wHck67ucSV',
#                                    'id': '0z4gvV4rjIZ9wHck67ucSV',
#                                    'name': 'Akon',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0z4gvV4rjIZ9wHck67ucSV'}],
#                       'disc_number': 1,
#                       'duration_ms': 238493,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USUR10300501'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0dNPpDFdvzj6XFIRzg2hmp'},
#                       'href': 'https://api.spotify.com/v1/tracks/0dNPpDFdvzj6XFIRzg2hmp',
#                       'id': '3BwkldhE22DdxOcXegF2Kv',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0dNPpDFdvzj6XFIRzg2hmp'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0dNPpDFdvzj6XFIRzg2hmp',
#                                       'id': '0dNPpDFdvzj6XFIRzg2hmp',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0dNPpDFdvzj6XFIRzg2hmp'},
#                       'name': 'Bananza (Belly Dancer)',
#                       'popularity': 0,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:3BwkldhE22DdxOcXegF2Kv'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1XkoF8ryArs86LZvFOkbyr'},
#                                              'href': 'https://api.spotify.com/v1/artists/1XkoF8ryArs86LZvFOkbyr',
#                                              'id': '1XkoF8ryArs86LZvFOkbyr',
#                                              'name': 'Mary J. Blige',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1XkoF8ryArs86LZvFOkbyr'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5QJmKwPveBV4IwLlo4OcG4'},
#                                 'href': 'https://api.spotify.com/v1/albums/5QJmKwPveBV4IwLlo4OcG4',
#                                 'id': '5QJmKwPveBV4IwLlo4OcG4',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273096a7fc9668305db9d3175fc',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02096a7fc9668305db9d3175fc',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851096a7fc9668305db9d3175fc',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'No More Drama',
#                                 'release_date': '2001-08-28',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 17,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5QJmKwPveBV4IwLlo4OcG4'},
# ...
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'},
#                                              'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw',
#                                              'id': '7qG3b048QCHVRO5Pv1T5lw',
#                                              'name': 'Enrique Iglesias',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3DeHyfe2Da8xznvABSfIE5'},
#                                 'href': 'https://api.spotify.com/v1/albums/3DeHyfe2Da8xznvABSfIE5',
#                                 'id': '3DeHyfe2Da8xznvABSfIE5',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27347527edce762c35fde07559c',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0247527edce762c35fde07559c',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485147527edce762c35fde07559c',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Escape',
#                                 'release_date': '2001-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 14,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3DeHyfe2Da8xznvABSfIE5'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7qG3b048QCHVRO5Pv1T5lw'},
#                                    'href': 'https://api.spotify.com/v1/artists/7qG3b048QCHVRO5Pv1T5lw',
#                                    'id': '7qG3b048QCHVRO5Pv1T5lw',
#                                    'name': 'Enrique Iglesias',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7qG3b048QCHVRO5Pv1T5lw'}],
#                       'disc_number': 1,
#                       'duration_ms': 264240,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10120047'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1PAgmT6YqGhd6zT9kN9gIo'},
#                       'href': 'https://api.spotify.com/v1/tracks/1PAgmT6YqGhd6zT9kN9gIo',
#                       'id': '1PAgmT6YqGhd6zT9kN9gIo',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Hero',
#                       'popularity': 65,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 4,
#                       'type': 'track',
#                       'uri': 'spotify:track:1PAgmT6YqGhd6zT9kN9gIo'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51Blml2LZPmy7TTiAg47vQ'},
#                                              'href': 'https://api.spotify.com/v1/artists/51Blml2LZPmy7TTiAg47vQ',
#                                              'id': '51Blml2LZPmy7TTiAg47vQ',
#                                              'name': 'U2',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:51Blml2LZPmy7TTiAg47vQ'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/7a5U0GPoAvT3gvEY66FRuN'},
#                                 'href': 'https://api.spotify.com/v1/albums/7a5U0GPoAvT3gvEY66FRuN',
#                                 'id': '7a5U0GPoAvT3gvEY66FRuN',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27338fa0dfe55b1ff2e8c962bae',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0238fa0dfe55b1ff2e8c962bae',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485138fa0dfe55b1ff2e8c962bae',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': "All That You Can't Leave Behind",
#                                 'release_date': '2000-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:7a5U0GPoAvT3gvEY66FRuN'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/51Blml2LZPmy7TTiAg47vQ'},
#                                    'href': 'https://api.spotify.com/v1/artists/51Blml2LZPmy7TTiAg47vQ',
#                                    'id': '51Blml2LZPmy7TTiAg47vQ',
#                                    'name': 'U2',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:51Blml2LZPmy7TTiAg47vQ'}],
#                       'disc_number': 1,
#                       'duration_ms': 248400,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GBAAN0000196'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0gzqZ9d1jIKo9psEIthwXe'},
#                       'href': 'https://api.spotify.com/v1/tracks/0gzqZ9d1jIKo9psEIthwXe',
#                       'id': '0gzqZ9d1jIKo9psEIthwXe',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Beautiful Day',
#                       'popularity': 72,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:0gzqZ9d1jIKo9psEIthwXe'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3q7HBObVc0L8jNeTe5Gofh'},
#                                              'href': 'https://api.spotify.com/v1/artists/3q7HBObVc0L8jNeTe5Gofh',
#                                              'id': '3q7HBObVc0L8jNeTe5Gofh',
#                                              'name': '50 Cent',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:3q7HBObVc0L8jNeTe5Gofh'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5G5rgQHzdQnw32SI0WjIo5'},
#                                 'href': 'https://api.spotify.com/v1/albums/5G5rgQHzdQnw32SI0WjIo5',
#                                 'id': '5G5rgQHzdQnw32SI0WjIo5',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273d843fabb75fef14010e30cae',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02d843fabb75fef14010e30cae',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851d843fabb75fef14010e30cae',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': "Get Rich Or Die Tryin'",
#                                 'release_date': '2003-02-06',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 20,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5G5rgQHzdQnw32SI0WjIo5'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3q7HBObVc0L8jNeTe5Gofh'},
#                                    'href': 'https://api.spotify.com/v1/artists/3q7HBObVc0L8jNeTe5Gofh',
#                                    'id': '3q7HBObVc0L8jNeTe5Gofh',
#                                    'name': '50 Cent',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:3q7HBObVc0L8jNeTe5Gofh'}],
#                       'disc_number': 1,
#                       'duration_ms': 193466,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USIR10300033'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/7iL6o9tox1zgHpKUfh9vuC'},
#                       'href': 'https://api.spotify.com/v1/tracks/7iL6o9tox1zgHpKUfh9vuC',
#                       'id': '7iL6o9tox1zgHpKUfh9vuC',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'In Da Club',
#                       'popularity': 81,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:7iL6o9tox1zgHpKUfh9vuC'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2022-06-01T03:19:45Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/best-of-the-best'},
#                          'href': 'https://api.spotify.com/v1/users/best-of-the-best',
#                          'id': 'best-of-the-best',
#                          'type': 'user',
#                          'uri': 'spotify:user:best-of-the-best'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#                                              'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#                                              'id': '4yiQZ8tQPux8cPriYMWUFP',
#                                              'name': 'Gwen Stefani',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/34y7m68F7rN9ou6m5GWohR'},
#                                 'href': 'https://api.spotify.com/v1/albums/34y7m68F7rN9ou6m5GWohR',
#                                 'id': '34y7m68F7rN9ou6m5GWohR',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273f049fc9322f0c93646cdcc77',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02f049fc9322f0c93646cdcc77',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851f049fc9322f0c93646cdcc77',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Love Angel Music Baby',
#                                 'release_date': '2004-11-22',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:34y7m68F7rN9ou6m5GWohR'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yiQZ8tQPux8cPriYMWUFP'},
#                                    'href': 'https://api.spotify.com/v1/artists/4yiQZ8tQPux8cPriYMWUFP',
#                                    'id': '4yiQZ8tQPux8cPriYMWUFP',
#                                    'name': 'Gwen Stefani',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:4yiQZ8tQPux8cPriYMWUFP'}],
#                       'disc_number': 1,
#                       'duration_ms': 199853,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USIR10400847'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0eqH0ALoDQevq59YcQ53KE'},
#                       'href': 'https://api.spotify.com/v1/tracks/0eqH0ALoDQevq59YcQ53KE',
#                       'id': '6KM6693N1wVvz6tDviEF4F',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0eqH0ALoDQevq59YcQ53KE'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0eqH0ALoDQevq59YcQ53KE',
#                                       'id': '0eqH0ALoDQevq59YcQ53KE',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0eqH0ALoDQevq59YcQ53KE'},
#                       'name': 'Hollaback Girl',
#                       'popularity': 70,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:6KM6693N1wVvz6tDviEF4F'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': None,
#  'offset': 0,
#  'previous': None,
#  'total': 73}

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials

# Initialize Spotipy with your credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="your_client_id", client_secret="your_client_secret"))

# Playlist ID of the "Best of 2000er" playlist
playlist_id = "2wjdNzVqTL0tDyIaWJQVqG"

# Get the tracks from the playlist
playlist = sp.user_playlist_tracks("spotify", playlist_id, market="GB")

# Lists to store the track IDs and song names
track_ids = []
song_names = []

# Iterate through all tracks in the playlist and save track IDs and names
for track in playlist['items']:
    track_ids.append(track['track']['id'])  # Track ID
    song_names.append(track['track']['name'])  # Song name

# Get the audio features for all tracks in the playlist
song_features = sp.audio_features(track_ids)

# Create a pandas DataFrame from the audio features
df = pd.DataFrame(song_features)

# Select relevant audio feature columns
df = df[["danceability", "energy", "loudness", "speechiness", "acousticness",
         "instrumentalness", "liveness", "valence", "tempo", "id", "duration_ms"]]

# Add the song names to the DataFrame
df["song_name"] = song_names

# Display the DataFrame
df.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.730   0.849    -5.281       0.0299       0.00234
# 1         0.501   0.809    -5.264       0.0938       0.03380
# 2         0.871   0.871    -6.328       0.1390       0.04690
# 3         0.834   0.699    -3.222       0.1780       0.11100
# 4         0.871   0.701    -5.594       0.0458       0.25700
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.000026    0.3120    0.887  117.308  4tKGFmENO69tZR9ahgZu48
# 1          0.006020    0.1190    0.258  149.964  456WNXWhDwYOSf5SpTuqxd
# 2          0.001140    0.0543    0.811  116.946  2aI21FnmY7TJVKeMaoQZ0t
# 3          0.000000    0.1310    0.809   94.086  0xmjwnQ3FNE6HuWCt2nHdZ
# 4          0.000008    0.0589    0.716  126.975  5r5cp9IpziiIsR6b93vcnQ
#
#    duration_ms                 song_name
# 0       230013  Murder On The Dancefloor
# 1       252819         Dog Days Are Over
# 2       223080              Say It Right
# 3       272533        Where Is The Love?
# 4       198440        Walking On A Dream

# %% [markdown]
# ### Example with rock

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %% [markdown]
# Example: Coldplay

# %% [markdown]
# ## Getting the songs of a given album
